# %%
#pip install noisereduce
#pip install scipy

# %%
# Global imports
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy import signal
from PIL import Image
import re
from mpl_toolkits.mplot3d import Axes3D
import librosa
import librosa.display

# %%
# Path to the directory containing folders with .wav files
root_path = "d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data"

# Define the root path for saving progress
PROGRESS_PATH = os.path.join(os.getcwd(), 'progress.txt')

# %%
# Function to generate spectrogram
    
def generate_mel_spectrogram(dataa, rate, save_path, resize_path):
    data = dataa.astype(np.float32)
    # Generate Mel spectrogram
    mel_spect = librosa.feature.melspectrogram(y=data, sr=rate, n_fft=2048, hop_length=1024)
    
    # Convert power spectrogram to dB scale
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    
    # Display the spectrogram
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mel_spect, y_axis='mel', fmax=8000, x_axis='time')
    #plt.title('Mel Spectrogram')
    #plt.colorbar(format='%+2.0f dB')
    plt.axis('off')  # Turn off axis labels
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)  # Save the figure
    plt.close()
    resize_image(save_path, (792, 252), resize_path)     
    
# Function to resize image
def resize_image(image_path, target_size, save_path):
    img = Image.open(image_path)
    img_resized = img.resize(target_size, resample=Image.Resampling.NEAREST)
    img_resized.save(save_path)

# %%
def apply_frequency_mask(spec, max_mask_pct=0.2, num_masks=5):
    """
    Apply frequency masking with multiple segments to a spectrogram.

    Parameters:
        spec (2D numpy array): Input spectrogram.
        max_mask_pct (float): Maximum percentage of frequencies to mask.
        num_masks (int): Number of masks to apply.

    Returns:
        masked_spec (2D numpy array): Spectrogram with frequency masking applied.
    """
    num_freqs = spec.shape[0]
    mask_length = int(max_mask_pct * num_freqs)

    # Randomly select starting frequencies for the masks
    start_idxs = np.random.randint(0, num_freqs - mask_length, size=num_masks)

    # Apply masks to the spectrogram
    masked_spec = np.copy(spec)
    for start_idx in start_idxs:
        end_idx = start_idx + mask_length
        masked_spec[start_idx:end_idx, :] = 0
        
    return masked_spec

# %%
def apply_time_mask(spec, max_mask_pct=0.2, num_masks=5):
    """
    Apply time masking with multiple segments to a spectrogram.

    Parameters:
        spec (2D numpy array): Input spectrogram.
        max_mask_pct (float): Maximum percentage of time steps to mask.
        num_masks (int): Number of masks to apply.

    Returns:
        masked_spec (2D numpy array): Spectrogram with time masking applied.
    """
    num_time_steps = spec.shape[1]
    mask_length = int(max_mask_pct * num_time_steps)

    # Randomly select starting time steps for the masks
    start_idxs = np.random.randint(0, num_time_steps - mask_length, size=num_masks)

    # Apply masks to the spectrogram
    masked_spec = np.copy(spec)
    for start_idx in start_idxs:
        end_idx = start_idx + mask_length
        masked_spec[:, start_idx:end_idx] = 0

    return masked_spec

# %%
# Function to save progress
def save_progress( wav_file_path):
    with open(PROGRESS_PATH, 'w') as file:
        file.write(wav_file_path)

# Function to load progress
def load_progress():
    progress_file = PROGRESS_PATH
    if os.path.exists(progress_file):
        with open(progress_file, 'r') as file:
            return file.read().strip()
    else:
        return None

# %%
def extract_numbers_from_string(input_string):
    # Regular expression to match numbers
    pattern = r'\d+'
    # Find all numbers in the input string
    numbers = re.findall(pattern, input_string)
    return numbers

# %%
def load_spectrogram(file_path):
    """Load a spectrogram from an image file."""
    # Open the image file
    img = Image.open(file_path)

    # Convert the image to a numpy array
    spec = np.array(img)

    return spec

# %%
def save_spectrogram(spec, save_path, rotate_180=True):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(spec, y_axis='mel', fmax=8000, x_axis='time')
    #plt.title('Mel Spectrogram')
    #plt.colorbar(format='%+2.0f dB')
    plt.axis('off')  # Turn off axis labels
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)  # Save the figure
    plt.close()
    
    if rotate_180:
        # Load the saved image and rotate it by 180 degrees
        img = plt.imread(save_path)
        img_rotated = np.rot90(img, 2)
        
        # Flip the rotated image horizontally to revert the mirror effect
        img_rotated_flipped = np.fliplr(img_rotated)
        
        # Save the flipped image
        plt.imsave(save_path, img_rotated_flipped)

# %%
def apply_augmentation(save_path, spec, max_mask_pct = 0.01, num_masks = 10 ):
    freq = apply_frequency_mask(spec, max_mask_pct, num_masks )
    time = apply_time_mask(spec, max_mask_pct, num_masks)
    save_spectrogram(freq, save_path + f'_FREQ.jpg')
    save_spectrogram(time, save_path + f'_TIME.jpg')

# %%
def resize_and_save_image(input_path, output_path, target_size=(792, 252)):
    """Resize an image and save it to the output path."""
    # Open the image
    img = Image.open(input_path)
    
    # Resize the image
    img_resized = img.resize(target_size)
    
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    # Save the resized image
    img_resized.save(output_path)

# %%
# Load progress
last_wav_file_path = load_progress()
# Seek and get
for folder_name in os.listdir(root_path):
    folder_path = os.path.join(root_path, folder_name)
    normal_path = folder_path +'/normal/'
    resized_path = folder_path +'/resized/'
    number_file = extract_numbers_from_string(folder_name)
    
    if os.path.isdir(folder_path):
        print(folder_path)
        print(last_wav_file_path)
        
        #if last_wav_file_path!= None and extract_numbers_from_string(folder_path) < extract_numbers_from_string(last_wav_file_path):
#            continue
        original_spec = load_spectrogram(os.path.join(normal_path ,'spectrogram_cleaned_'+number_file[0]+'_AUDIO.jpg'))
        apply_augmentation(normal_path +f'spectrogram_cleaned_{number_file[0]}_AUDIO', original_spec)
        
        preprocessed_spec = load_spectrogram(normal_path +f'spectrogram_cleaned_preprocessed_{number_file[0]}_AUDIO.jpg')
        apply_augmentation(normal_path +f'spectrogram_preprocessed_{number_file[0]}_AUDIO', preprocessed_spec)
                   
        for image_file in glob.glob(os.path.join(normal_path, '*.jpg')):
             # Extract the audio file name without extension
            image_file_name = os.path.splitext(os.path.basename(image_file))[0]
            print(image_file_name)
            # Resize and save
            resize_and_save_image(os.path.join(normal_path,image_file_name+'.jpg'), os.path.join(resized_path, image_file_name+'.jpg'))
            # Save progress
            save_progress(folder_path)

            # Delete original spectrogram
            #os.remove(spectrogram_save_path)
# Out:
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\300_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_300_AUDIO
# spectrogram_cleaned_300_AUDIO_FREQ
# spectrogram_cleaned_300_AUDIO_TIME
# spectrogram_cleaned_preprocessed_300_AUDIO
# spectrogram_preprocessed_300_AUDIO_FREQ
# spectrogram_preprocessed_300_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\301_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_301_AUDIO
# spectrogram_cleaned_301_AUDIO_FREQ
# spectrogram_cleaned_301_AUDIO_TIME
# spectrogram_cleaned_preprocessed_301_AUDIO
# spectrogram_preprocessed_301_AUDIO_FREQ
# spectrogram_preprocessed_301_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\302_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_302_AUDIO
# spectrogram_cleaned_302_AUDIO_FREQ
# spectrogram_cleaned_302_AUDIO_TIME
# spectrogram_cleaned_preprocessed_302_AUDIO
# spectrogram_preprocessed_302_AUDIO_FREQ
# spectrogram_preprocessed_302_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\303_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_303_AUDIO
# spectrogram_cleaned_303_AUDIO_FREQ
# spectrogram_cleaned_303_AUDIO_TIME
# spectrogram_cleaned_preprocessed_303_AUDIO
# spectrogram_preprocessed_303_AUDIO_FREQ
# spectrogram_preprocessed_303_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\304_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_304_AUDIO
# spectrogram_cleaned_304_AUDIO_FREQ
# spectrogram_cleaned_304_AUDIO_TIME
# spectrogram_cleaned_preprocessed_304_AUDIO
# spectrogram_preprocessed_304_AUDIO_FREQ
# spectrogram_preprocessed_304_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\305_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_305_AUDIO
# spectrogram_cleaned_305_AUDIO_FREQ
# spectrogram_cleaned_305_AUDIO_TIME
# spectrogram_cleaned_preprocessed_305_AUDIO
# spectrogram_preprocessed_305_AUDIO_FREQ
# spectrogram_preprocessed_305_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\306_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_306_AUDIO
# spectrogram_cleaned_306_AUDIO_FREQ
# spectrogram_cleaned_306_AUDIO_TIME
# spectrogram_cleaned_preprocessed_306_AUDIO
# spectrogram_preprocessed_306_AUDIO_FREQ
# spectrogram_preprocessed_306_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\307_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_307_AUDIO
# spectrogram_cleaned_307_AUDIO_FREQ
# spectrogram_cleaned_307_AUDIO_TIME
# spectrogram_cleaned_preprocessed_307_AUDIO
# spectrogram_preprocessed_307_AUDIO_FREQ
# spectrogram_preprocessed_307_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\308_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_308_AUDIO
# spectrogram_cleaned_308_AUDIO_FREQ
# spectrogram_cleaned_308_AUDIO_TIME
# spectrogram_cleaned_preprocessed_308_AUDIO
# spectrogram_preprocessed_308_AUDIO_FREQ
# spectrogram_preprocessed_308_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\309_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_309_AUDIO
# spectrogram_cleaned_309_AUDIO_FREQ
# spectrogram_cleaned_309_AUDIO_TIME
# spectrogram_cleaned_preprocessed_309_AUDIO
# spectrogram_preprocessed_309_AUDIO_FREQ
# spectrogram_preprocessed_309_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\310_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_310_AUDIO
# spectrogram_cleaned_310_AUDIO_FREQ
# spectrogram_cleaned_310_AUDIO_TIME
# spectrogram_cleaned_preprocessed_310_AUDIO
# spectrogram_preprocessed_310_AUDIO_FREQ
# spectrogram_preprocessed_310_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\311_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_311_AUDIO
# spectrogram_cleaned_311_AUDIO_FREQ
# spectrogram_cleaned_311_AUDIO_TIME
# spectrogram_cleaned_preprocessed_311_AUDIO
# spectrogram_preprocessed_311_AUDIO_FREQ
# spectrogram_preprocessed_311_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\312_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_312_AUDIO
# spectrogram_cleaned_312_AUDIO_FREQ
# spectrogram_cleaned_312_AUDIO_TIME
# spectrogram_cleaned_preprocessed_312_AUDIO
# spectrogram_preprocessed_312_AUDIO_FREQ
# spectrogram_preprocessed_312_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\313_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_313_AUDIO
# spectrogram_cleaned_313_AUDIO_FREQ
# spectrogram_cleaned_313_AUDIO_TIME
# spectrogram_cleaned_preprocessed_313_AUDIO
# spectrogram_preprocessed_313_AUDIO_FREQ
# spectrogram_preprocessed_313_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\314_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_314_AUDIO
# spectrogram_cleaned_314_AUDIO_FREQ
# spectrogram_cleaned_314_AUDIO_TIME
# spectrogram_cleaned_preprocessed_314_AUDIO
# spectrogram_preprocessed_314_AUDIO_FREQ
# spectrogram_preprocessed_314_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\315_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_315_AUDIO
# spectrogram_cleaned_315_AUDIO_FREQ
# spectrogram_cleaned_315_AUDIO_TIME
# spectrogram_cleaned_preprocessed_315_AUDIO
# spectrogram_preprocessed_315_AUDIO_FREQ
# spectrogram_preprocessed_315_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_316_AUDIO
# spectrogram_cleaned_316_AUDIO_FREQ
# spectrogram_cleaned_316_AUDIO_TIME
# spectrogram_cleaned_preprocessed_316_AUDIO
# spectrogram_preprocessed_316_AUDIO_FREQ
# spectrogram_preprocessed_316_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\317_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_317_AUDIO
# spectrogram_cleaned_317_AUDIO_FREQ
# spectrogram_cleaned_317_AUDIO_TIME
# spectrogram_cleaned_preprocessed_317_AUDIO
# spectrogram_preprocessed_317_AUDIO_FREQ
# spectrogram_preprocessed_317_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\318_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_318_AUDIO
# spectrogram_cleaned_318_AUDIO_FREQ
# spectrogram_cleaned_318_AUDIO_TIME
# spectrogram_cleaned_preprocessed_318_AUDIO
# spectrogram_preprocessed_318_AUDIO_FREQ
# spectrogram_preprocessed_318_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\319_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_319_AUDIO
# spectrogram_cleaned_319_AUDIO_FREQ
# spectrogram_cleaned_319_AUDIO_TIME
# spectrogram_cleaned_preprocessed_319_AUDIO
# spectrogram_preprocessed_319_AUDIO_FREQ
# spectrogram_preprocessed_319_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\320_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_320_AUDIO
# spectrogram_cleaned_320_AUDIO_FREQ
# spectrogram_cleaned_320_AUDIO_TIME
# spectrogram_cleaned_preprocessed_320_AUDIO
# spectrogram_preprocessed_320_AUDIO_FREQ
# spectrogram_preprocessed_320_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\321_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_321_AUDIO
# spectrogram_cleaned_321_AUDIO_FREQ
# spectrogram_cleaned_321_AUDIO_TIME
# spectrogram_cleaned_preprocessed_321_AUDIO
# spectrogram_preprocessed_321_AUDIO_FREQ
# spectrogram_preprocessed_321_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\322_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_322_AUDIO
# spectrogram_cleaned_322_AUDIO_FREQ
# spectrogram_cleaned_322_AUDIO_TIME
# spectrogram_cleaned_preprocessed_322_AUDIO
# spectrogram_preprocessed_322_AUDIO_FREQ
# spectrogram_preprocessed_322_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\323_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_323_AUDIO
# spectrogram_cleaned_323_AUDIO_FREQ
# spectrogram_cleaned_323_AUDIO_TIME
# spectrogram_cleaned_preprocessed_323_AUDIO
# spectrogram_preprocessed_323_AUDIO_FREQ
# spectrogram_preprocessed_323_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\324_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_324_AUDIO
# spectrogram_cleaned_324_AUDIO_FREQ
# spectrogram_cleaned_324_AUDIO_TIME
# spectrogram_cleaned_preprocessed_324_AUDIO
# spectrogram_preprocessed_324_AUDIO_FREQ
# spectrogram_preprocessed_324_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\325_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_325_AUDIO
# spectrogram_cleaned_325_AUDIO_FREQ
# spectrogram_cleaned_325_AUDIO_TIME
# spectrogram_cleaned_preprocessed_325_AUDIO
# spectrogram_preprocessed_325_AUDIO_FREQ
# spectrogram_preprocessed_325_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\326_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_326_AUDIO
# spectrogram_cleaned_326_AUDIO_FREQ
# spectrogram_cleaned_326_AUDIO_TIME
# spectrogram_cleaned_preprocessed_326_AUDIO
# spectrogram_preprocessed_326_AUDIO_FREQ
# spectrogram_preprocessed_326_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\327_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_327_AUDIO
# spectrogram_cleaned_327_AUDIO_FREQ
# spectrogram_cleaned_327_AUDIO_TIME
# spectrogram_cleaned_preprocessed_327_AUDIO
# spectrogram_preprocessed_327_AUDIO_FREQ
# spectrogram_preprocessed_327_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\328_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_328_AUDIO
# spectrogram_cleaned_328_AUDIO_FREQ
# spectrogram_cleaned_328_AUDIO_TIME
# spectrogram_cleaned_preprocessed_328_AUDIO
# spectrogram_preprocessed_328_AUDIO_FREQ
# spectrogram_preprocessed_328_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\329_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_329_AUDIO
# spectrogram_cleaned_329_AUDIO_FREQ
# spectrogram_cleaned_329_AUDIO_TIME
# spectrogram_cleaned_preprocessed_329_AUDIO
# spectrogram_preprocessed_329_AUDIO_FREQ
# spectrogram_preprocessed_329_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\330_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_330_AUDIO
# spectrogram_cleaned_330_AUDIO_FREQ
# spectrogram_cleaned_330_AUDIO_TIME
# spectrogram_cleaned_preprocessed_330_AUDIO
# spectrogram_preprocessed_330_AUDIO_FREQ
# spectrogram_preprocessed_330_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\331_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_331_AUDIO
# spectrogram_cleaned_331_AUDIO_FREQ
# spectrogram_cleaned_331_AUDIO_TIME
# spectrogram_cleaned_preprocessed_331_AUDIO
# spectrogram_preprocessed_331_AUDIO_FREQ
# spectrogram_preprocessed_331_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\332_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_332_AUDIO
# spectrogram_cleaned_332_AUDIO_FREQ
# spectrogram_cleaned_332_AUDIO_TIME
# spectrogram_cleaned_preprocessed_332_AUDIO
# spectrogram_preprocessed_332_AUDIO_FREQ
# spectrogram_preprocessed_332_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\333_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_333_AUDIO
# spectrogram_cleaned_333_AUDIO_FREQ
# spectrogram_cleaned_333_AUDIO_TIME
# spectrogram_cleaned_preprocessed_333_AUDIO
# spectrogram_preprocessed_333_AUDIO_FREQ
# spectrogram_preprocessed_333_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\334_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_334_AUDIO
# spectrogram_cleaned_334_AUDIO_FREQ
# spectrogram_cleaned_334_AUDIO_TIME
# spectrogram_cleaned_preprocessed_334_AUDIO
# spectrogram_preprocessed_334_AUDIO_FREQ
# spectrogram_preprocessed_334_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\335_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_335_AUDIO
# spectrogram_cleaned_335_AUDIO_FREQ
# spectrogram_cleaned_335_AUDIO_TIME
# spectrogram_cleaned_preprocessed_335_AUDIO
# spectrogram_preprocessed_335_AUDIO_FREQ
# spectrogram_preprocessed_335_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\336_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_336_AUDIO
# spectrogram_cleaned_336_AUDIO_FREQ
# spectrogram_cleaned_336_AUDIO_TIME
# spectrogram_cleaned_preprocessed_336_AUDIO
# spectrogram_preprocessed_336_AUDIO_FREQ
# spectrogram_preprocessed_336_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\337_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_337_AUDIO
# spectrogram_cleaned_337_AUDIO_FREQ
# spectrogram_cleaned_337_AUDIO_TIME
# spectrogram_cleaned_preprocessed_337_AUDIO
# spectrogram_preprocessed_337_AUDIO_FREQ
# spectrogram_preprocessed_337_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\338_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_338_AUDIO
# spectrogram_cleaned_338_AUDIO_FREQ
# spectrogram_cleaned_338_AUDIO_TIME
# spectrogram_cleaned_preprocessed_338_AUDIO
# spectrogram_preprocessed_338_AUDIO_FREQ
# spectrogram_preprocessed_338_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\339_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_339_AUDIO
# spectrogram_cleaned_339_AUDIO_FREQ
# spectrogram_cleaned_339_AUDIO_TIME
# spectrogram_cleaned_preprocessed_339_AUDIO
# spectrogram_preprocessed_339_AUDIO_FREQ
# spectrogram_preprocessed_339_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\340_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_340_AUDIO
# spectrogram_cleaned_340_AUDIO_FREQ
# spectrogram_cleaned_340_AUDIO_TIME
# spectrogram_cleaned_preprocessed_340_AUDIO
# spectrogram_preprocessed_340_AUDIO_FREQ
# spectrogram_preprocessed_340_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\341_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_341_AUDIO
# spectrogram_cleaned_341_AUDIO_FREQ
# spectrogram_cleaned_341_AUDIO_TIME
# spectrogram_cleaned_preprocessed_341_AUDIO
# spectrogram_preprocessed_341_AUDIO_FREQ
# spectrogram_preprocessed_341_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\343_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_343_AUDIO
# spectrogram_cleaned_343_AUDIO_FREQ
# spectrogram_cleaned_343_AUDIO_TIME
# spectrogram_cleaned_preprocessed_343_AUDIO
# spectrogram_preprocessed_343_AUDIO_FREQ
# spectrogram_preprocessed_343_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\344_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_344_AUDIO
# spectrogram_cleaned_344_AUDIO_FREQ
# spectrogram_cleaned_344_AUDIO_TIME
# spectrogram_cleaned_preprocessed_344_AUDIO
# spectrogram_preprocessed_344_AUDIO_FREQ
# spectrogram_preprocessed_344_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\345_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_345_AUDIO
# spectrogram_cleaned_345_AUDIO_FREQ
# spectrogram_cleaned_345_AUDIO_TIME
# spectrogram_cleaned_preprocessed_345_AUDIO
# spectrogram_preprocessed_345_AUDIO_FREQ
# spectrogram_preprocessed_345_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\346_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_346_AUDIO
# spectrogram_cleaned_346_AUDIO_FREQ
# spectrogram_cleaned_346_AUDIO_TIME
# spectrogram_cleaned_preprocessed_346_AUDIO
# spectrogram_preprocessed_346_AUDIO_FREQ
# spectrogram_preprocessed_346_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\347_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_347_AUDIO
# spectrogram_cleaned_347_AUDIO_FREQ
# spectrogram_cleaned_347_AUDIO_TIME
# spectrogram_cleaned_preprocessed_347_AUDIO
# spectrogram_preprocessed_347_AUDIO_FREQ
# spectrogram_preprocessed_347_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\348_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_348_AUDIO
# spectrogram_cleaned_348_AUDIO_FREQ
# spectrogram_cleaned_348_AUDIO_TIME
# spectrogram_cleaned_preprocessed_348_AUDIO
# spectrogram_preprocessed_348_AUDIO_FREQ
# spectrogram_preprocessed_348_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\349_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_349_AUDIO
# spectrogram_cleaned_349_AUDIO_FREQ
# spectrogram_cleaned_349_AUDIO_TIME
# spectrogram_cleaned_preprocessed_349_AUDIO
# spectrogram_preprocessed_349_AUDIO_FREQ
# spectrogram_preprocessed_349_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\350_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_350_AUDIO
# spectrogram_cleaned_350_AUDIO_FREQ
# spectrogram_cleaned_350_AUDIO_TIME
# spectrogram_cleaned_preprocessed_350_AUDIO
# spectrogram_preprocessed_350_AUDIO_FREQ
# spectrogram_preprocessed_350_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\351_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_351_AUDIO
# spectrogram_cleaned_351_AUDIO_FREQ
# spectrogram_cleaned_351_AUDIO_TIME
# spectrogram_cleaned_preprocessed_351_AUDIO
# spectrogram_preprocessed_351_AUDIO_FREQ
# spectrogram_preprocessed_351_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\352_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_352_AUDIO
# spectrogram_cleaned_352_AUDIO_FREQ
# spectrogram_cleaned_352_AUDIO_TIME
# spectrogram_cleaned_preprocessed_352_AUDIO
# spectrogram_preprocessed_352_AUDIO_FREQ
# spectrogram_preprocessed_352_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\353_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_353_AUDIO
# spectrogram_cleaned_353_AUDIO_FREQ
# spectrogram_cleaned_353_AUDIO_TIME
# spectrogram_cleaned_preprocessed_353_AUDIO
# spectrogram_preprocessed_353_AUDIO_FREQ
# spectrogram_preprocessed_353_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\354_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_354_AUDIO
# spectrogram_cleaned_354_AUDIO_FREQ
# spectrogram_cleaned_354_AUDIO_TIME
# spectrogram_cleaned_preprocessed_354_AUDIO
# spectrogram_preprocessed_354_AUDIO_FREQ
# spectrogram_preprocessed_354_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\355_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_355_AUDIO
# spectrogram_cleaned_355_AUDIO_FREQ
# spectrogram_cleaned_355_AUDIO_TIME
# spectrogram_cleaned_preprocessed_355_AUDIO
# spectrogram_preprocessed_355_AUDIO_FREQ
# spectrogram_preprocessed_355_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\356_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_356_AUDIO
# spectrogram_cleaned_356_AUDIO_FREQ
# spectrogram_cleaned_356_AUDIO_TIME
# spectrogram_cleaned_preprocessed_356_AUDIO
# spectrogram_preprocessed_356_AUDIO_FREQ
# spectrogram_preprocessed_356_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\357_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_357_AUDIO
# spectrogram_cleaned_357_AUDIO_FREQ
# spectrogram_cleaned_357_AUDIO_TIME
# spectrogram_cleaned_preprocessed_357_AUDIO
# spectrogram_preprocessed_357_AUDIO_FREQ
# spectrogram_preprocessed_357_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\358_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_358_AUDIO
# spectrogram_cleaned_358_AUDIO_FREQ
# spectrogram_cleaned_358_AUDIO_TIME
# spectrogram_cleaned_preprocessed_358_AUDIO
# spectrogram_preprocessed_358_AUDIO_FREQ
# spectrogram_preprocessed_358_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\359_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_359_AUDIO
# spectrogram_cleaned_359_AUDIO_FREQ
# spectrogram_cleaned_359_AUDIO_TIME
# spectrogram_cleaned_preprocessed_359_AUDIO
# spectrogram_preprocessed_359_AUDIO_FREQ
# spectrogram_preprocessed_359_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\360_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_360_AUDIO
# spectrogram_cleaned_360_AUDIO_FREQ
# spectrogram_cleaned_360_AUDIO_TIME
# spectrogram_cleaned_preprocessed_360_AUDIO
# spectrogram_preprocessed_360_AUDIO_FREQ
# spectrogram_preprocessed_360_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\361_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_361_AUDIO
# spectrogram_cleaned_361_AUDIO_FREQ
# spectrogram_cleaned_361_AUDIO_TIME
# spectrogram_cleaned_preprocessed_361_AUDIO
# spectrogram_preprocessed_361_AUDIO_FREQ
# spectrogram_preprocessed_361_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\362_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_362_AUDIO
# spectrogram_cleaned_362_AUDIO_FREQ
# spectrogram_cleaned_362_AUDIO_TIME
# spectrogram_cleaned_preprocessed_362_AUDIO
# spectrogram_preprocessed_362_AUDIO_FREQ
# spectrogram_preprocessed_362_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\363_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_363_AUDIO
# spectrogram_cleaned_363_AUDIO_FREQ
# spectrogram_cleaned_363_AUDIO_TIME
# spectrogram_cleaned_preprocessed_363_AUDIO
# spectrogram_preprocessed_363_AUDIO_FREQ
# spectrogram_preprocessed_363_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\364_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_364_AUDIO
# spectrogram_cleaned_364_AUDIO_FREQ
# spectrogram_cleaned_364_AUDIO_TIME
# spectrogram_cleaned_preprocessed_364_AUDIO
# spectrogram_preprocessed_364_AUDIO_FREQ
# spectrogram_preprocessed_364_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\365_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_365_AUDIO
# spectrogram_cleaned_365_AUDIO_FREQ
# spectrogram_cleaned_365_AUDIO_TIME
# spectrogram_cleaned_preprocessed_365_AUDIO
# spectrogram_preprocessed_365_AUDIO_FREQ
# spectrogram_preprocessed_365_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\366_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_366_AUDIO
# spectrogram_cleaned_366_AUDIO_FREQ
# spectrogram_cleaned_366_AUDIO_TIME
# spectrogram_cleaned_preprocessed_366_AUDIO
# spectrogram_preprocessed_366_AUDIO_FREQ
# spectrogram_preprocessed_366_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\367_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_367_AUDIO
# spectrogram_cleaned_367_AUDIO_FREQ
# spectrogram_cleaned_367_AUDIO_TIME
# spectrogram_cleaned_preprocessed_367_AUDIO
# spectrogram_preprocessed_367_AUDIO_FREQ
# spectrogram_preprocessed_367_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\368_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_368_AUDIO
# spectrogram_cleaned_368_AUDIO_FREQ
# spectrogram_cleaned_368_AUDIO_TIME
# spectrogram_cleaned_preprocessed_368_AUDIO
# spectrogram_preprocessed_368_AUDIO_FREQ
# spectrogram_preprocessed_368_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\369_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_369_AUDIO
# spectrogram_cleaned_369_AUDIO_FREQ
# spectrogram_cleaned_369_AUDIO_TIME
# spectrogram_cleaned_preprocessed_369_AUDIO
# spectrogram_preprocessed_369_AUDIO_FREQ
# spectrogram_preprocessed_369_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\370_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_370_AUDIO
# spectrogram_cleaned_370_AUDIO_FREQ
# spectrogram_cleaned_370_AUDIO_TIME
# spectrogram_cleaned_preprocessed_370_AUDIO
# spectrogram_preprocessed_370_AUDIO_FREQ
# spectrogram_preprocessed_370_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\371_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_371_AUDIO
# spectrogram_cleaned_371_AUDIO_FREQ
# spectrogram_cleaned_371_AUDIO_TIME
# spectrogram_cleaned_preprocessed_371_AUDIO
# spectrogram_preprocessed_371_AUDIO_FREQ
# spectrogram_preprocessed_371_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\372_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_372_AUDIO
# spectrogram_cleaned_372_AUDIO_FREQ
# spectrogram_cleaned_372_AUDIO_TIME
# spectrogram_cleaned_preprocessed_372_AUDIO
# spectrogram_preprocessed_372_AUDIO_FREQ
# spectrogram_preprocessed_372_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\373_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_373_AUDIO
# spectrogram_cleaned_373_AUDIO_FREQ
# spectrogram_cleaned_373_AUDIO_TIME
# spectrogram_cleaned_preprocessed_373_AUDIO
# spectrogram_preprocessed_373_AUDIO_FREQ
# spectrogram_preprocessed_373_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\374_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_374_AUDIO
# spectrogram_cleaned_374_AUDIO_FREQ
# spectrogram_cleaned_374_AUDIO_TIME
# spectrogram_cleaned_preprocessed_374_AUDIO
# spectrogram_preprocessed_374_AUDIO_FREQ
# spectrogram_preprocessed_374_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\375_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_375_AUDIO
# spectrogram_cleaned_375_AUDIO_FREQ
# spectrogram_cleaned_375_AUDIO_TIME
# spectrogram_cleaned_preprocessed_375_AUDIO
# spectrogram_preprocessed_375_AUDIO_FREQ
# spectrogram_preprocessed_375_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\376_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_376_AUDIO
# spectrogram_cleaned_376_AUDIO_FREQ
# spectrogram_cleaned_376_AUDIO_TIME
# spectrogram_cleaned_preprocessed_376_AUDIO
# spectrogram_preprocessed_376_AUDIO_FREQ
# spectrogram_preprocessed_376_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\377_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_377_AUDIO
# spectrogram_cleaned_377_AUDIO_FREQ
# spectrogram_cleaned_377_AUDIO_TIME
# spectrogram_cleaned_preprocessed_377_AUDIO
# spectrogram_preprocessed_377_AUDIO_FREQ
# spectrogram_preprocessed_377_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\378_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_378_AUDIO
# spectrogram_cleaned_378_AUDIO_FREQ
# spectrogram_cleaned_378_AUDIO_TIME
# spectrogram_cleaned_preprocessed_378_AUDIO
# spectrogram_preprocessed_378_AUDIO_FREQ
# spectrogram_preprocessed_378_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\379_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_379_AUDIO
# spectrogram_cleaned_379_AUDIO_FREQ
# spectrogram_cleaned_379_AUDIO_TIME
# spectrogram_cleaned_preprocessed_379_AUDIO
# spectrogram_preprocessed_379_AUDIO_FREQ
# spectrogram_preprocessed_379_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\380_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_380_AUDIO
# spectrogram_cleaned_380_AUDIO_FREQ
# spectrogram_cleaned_380_AUDIO_TIME
# spectrogram_cleaned_preprocessed_380_AUDIO
# spectrogram_preprocessed_380_AUDIO_FREQ
# spectrogram_preprocessed_380_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\381_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_381_AUDIO
# spectrogram_cleaned_381_AUDIO_FREQ
# spectrogram_cleaned_381_AUDIO_TIME
# spectrogram_cleaned_preprocessed_381_AUDIO
# spectrogram_preprocessed_381_AUDIO_FREQ
# spectrogram_preprocessed_381_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\382_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_382_AUDIO
# spectrogram_cleaned_382_AUDIO_FREQ
# spectrogram_cleaned_382_AUDIO_TIME
# spectrogram_cleaned_preprocessed_382_AUDIO
# spectrogram_preprocessed_382_AUDIO_FREQ
# spectrogram_preprocessed_382_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\383_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_383_AUDIO
# spectrogram_cleaned_383_AUDIO_FREQ
# spectrogram_cleaned_383_AUDIO_TIME
# spectrogram_cleaned_preprocessed_383_AUDIO
# spectrogram_preprocessed_383_AUDIO_FREQ
# spectrogram_preprocessed_383_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\384_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_384_AUDIO
# spectrogram_cleaned_384_AUDIO_FREQ
# spectrogram_cleaned_384_AUDIO_TIME
# spectrogram_cleaned_preprocessed_384_AUDIO
# spectrogram_preprocessed_384_AUDIO_FREQ
# spectrogram_preprocessed_384_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\385_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_385_AUDIO
# spectrogram_cleaned_385_AUDIO_FREQ
# spectrogram_cleaned_385_AUDIO_TIME
# spectrogram_cleaned_preprocessed_385_AUDIO
# spectrogram_preprocessed_385_AUDIO_FREQ
# spectrogram_preprocessed_385_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\386_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_386_AUDIO
# spectrogram_cleaned_386_AUDIO_FREQ
# spectrogram_cleaned_386_AUDIO_TIME
# spectrogram_cleaned_preprocessed_386_AUDIO
# spectrogram_preprocessed_386_AUDIO_FREQ
# spectrogram_preprocessed_386_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\387_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_387_AUDIO
# spectrogram_cleaned_387_AUDIO_FREQ
# spectrogram_cleaned_387_AUDIO_TIME
# spectrogram_cleaned_preprocessed_387_AUDIO
# spectrogram_preprocessed_387_AUDIO_FREQ
# spectrogram_preprocessed_387_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\388_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_388_AUDIO
# spectrogram_cleaned_388_AUDIO_FREQ
# spectrogram_cleaned_388_AUDIO_TIME
# spectrogram_cleaned_preprocessed_388_AUDIO
# spectrogram_preprocessed_388_AUDIO_FREQ
# spectrogram_preprocessed_388_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\389_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_389_AUDIO
# spectrogram_cleaned_389_AUDIO_FREQ
# spectrogram_cleaned_389_AUDIO_TIME
# spectrogram_cleaned_preprocessed_389_AUDIO
# spectrogram_preprocessed_389_AUDIO_FREQ
# spectrogram_preprocessed_389_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\390_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_390_AUDIO
# spectrogram_cleaned_390_AUDIO_FREQ
# spectrogram_cleaned_390_AUDIO_TIME
# spectrogram_cleaned_preprocessed_390_AUDIO
# spectrogram_preprocessed_390_AUDIO_FREQ
# spectrogram_preprocessed_390_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\391_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_391_AUDIO
# spectrogram_cleaned_391_AUDIO_FREQ
# spectrogram_cleaned_391_AUDIO_TIME
# spectrogram_cleaned_preprocessed_391_AUDIO
# spectrogram_preprocessed_391_AUDIO_FREQ
# spectrogram_preprocessed_391_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\392_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_392_AUDIO
# spectrogram_cleaned_392_AUDIO_FREQ
# spectrogram_cleaned_392_AUDIO_TIME
# spectrogram_cleaned_preprocessed_392_AUDIO
# spectrogram_preprocessed_392_AUDIO_FREQ
# spectrogram_preprocessed_392_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\393_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_393_AUDIO
# spectrogram_cleaned_393_AUDIO_FREQ
# spectrogram_cleaned_393_AUDIO_TIME
# spectrogram_cleaned_preprocessed_393_AUDIO
# spectrogram_preprocessed_393_AUDIO_FREQ
# spectrogram_preprocessed_393_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\395_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_395_AUDIO
# spectrogram_cleaned_395_AUDIO_FREQ
# spectrogram_cleaned_395_AUDIO_TIME
# spectrogram_cleaned_preprocessed_395_AUDIO
# spectrogram_preprocessed_395_AUDIO_FREQ
# spectrogram_preprocessed_395_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\396_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_396_AUDIO
# spectrogram_cleaned_396_AUDIO_FREQ
# spectrogram_cleaned_396_AUDIO_TIME
# spectrogram_cleaned_preprocessed_396_AUDIO
# spectrogram_preprocessed_396_AUDIO_FREQ
# spectrogram_preprocessed_396_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\397_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_397_AUDIO
# spectrogram_cleaned_397_AUDIO_FREQ
# spectrogram_cleaned_397_AUDIO_TIME
# spectrogram_cleaned_preprocessed_397_AUDIO
# spectrogram_preprocessed_397_AUDIO_FREQ
# spectrogram_preprocessed_397_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\399_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_399_AUDIO
# spectrogram_cleaned_399_AUDIO_FREQ
# spectrogram_cleaned_399_AUDIO_TIME
# spectrogram_cleaned_preprocessed_399_AUDIO
# spectrogram_preprocessed_399_AUDIO_FREQ
# spectrogram_preprocessed_399_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\400_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_400_AUDIO
# spectrogram_cleaned_400_AUDIO_FREQ
# spectrogram_cleaned_400_AUDIO_TIME
# spectrogram_cleaned_preprocessed_400_AUDIO
# spectrogram_preprocessed_400_AUDIO_FREQ
# spectrogram_preprocessed_400_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\401_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_401_AUDIO
# spectrogram_cleaned_401_AUDIO_FREQ
# spectrogram_cleaned_401_AUDIO_TIME
# spectrogram_cleaned_preprocessed_401_AUDIO
# spectrogram_preprocessed_401_AUDIO_FREQ
# spectrogram_preprocessed_401_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\402_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_402_AUDIO
# spectrogram_cleaned_402_AUDIO_FREQ
# spectrogram_cleaned_402_AUDIO_TIME
# spectrogram_cleaned_preprocessed_402_AUDIO
# spectrogram_preprocessed_402_AUDIO_FREQ
# spectrogram_preprocessed_402_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\403_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_403_AUDIO
# spectrogram_cleaned_403_AUDIO_FREQ
# spectrogram_cleaned_403_AUDIO_TIME
# spectrogram_cleaned_preprocessed_403_AUDIO
# spectrogram_preprocessed_403_AUDIO_FREQ
# spectrogram_preprocessed_403_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\404_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_404_AUDIO
# spectrogram_cleaned_404_AUDIO_FREQ
# spectrogram_cleaned_404_AUDIO_TIME
# spectrogram_cleaned_preprocessed_404_AUDIO
# spectrogram_preprocessed_404_AUDIO_FREQ
# spectrogram_preprocessed_404_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\405_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_405_AUDIO
# spectrogram_cleaned_405_AUDIO_FREQ
# spectrogram_cleaned_405_AUDIO_TIME
# spectrogram_cleaned_preprocessed_405_AUDIO
# spectrogram_preprocessed_405_AUDIO_FREQ
# spectrogram_preprocessed_405_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\406_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_406_AUDIO
# spectrogram_cleaned_406_AUDIO_FREQ
# spectrogram_cleaned_406_AUDIO_TIME
# spectrogram_cleaned_preprocessed_406_AUDIO
# spectrogram_preprocessed_406_AUDIO_FREQ
# spectrogram_preprocessed_406_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\407_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_407_AUDIO
# spectrogram_cleaned_407_AUDIO_FREQ
# spectrogram_cleaned_407_AUDIO_TIME
# spectrogram_cleaned_preprocessed_407_AUDIO
# spectrogram_preprocessed_407_AUDIO_FREQ
# spectrogram_preprocessed_407_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\408_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_408_AUDIO
# spectrogram_cleaned_408_AUDIO_FREQ
# spectrogram_cleaned_408_AUDIO_TIME
# spectrogram_cleaned_preprocessed_408_AUDIO
# spectrogram_preprocessed_408_AUDIO_FREQ
# spectrogram_preprocessed_408_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\409_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_409_AUDIO
# spectrogram_cleaned_409_AUDIO_FREQ
# spectrogram_cleaned_409_AUDIO_TIME
# spectrogram_cleaned_preprocessed_409_AUDIO
# spectrogram_preprocessed_409_AUDIO_FREQ
# spectrogram_preprocessed_409_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\410_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_410_AUDIO
# spectrogram_cleaned_410_AUDIO_FREQ
# spectrogram_cleaned_410_AUDIO_TIME
# spectrogram_cleaned_preprocessed_410_AUDIO
# spectrogram_preprocessed_410_AUDIO_FREQ
# spectrogram_preprocessed_410_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\411_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_411_AUDIO
# spectrogram_cleaned_411_AUDIO_FREQ
# spectrogram_cleaned_411_AUDIO_TIME
# spectrogram_cleaned_preprocessed_411_AUDIO
# spectrogram_preprocessed_411_AUDIO_FREQ
# spectrogram_preprocessed_411_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\412_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_412_AUDIO
# spectrogram_cleaned_412_AUDIO_FREQ
# spectrogram_cleaned_412_AUDIO_TIME
# spectrogram_cleaned_preprocessed_412_AUDIO
# spectrogram_preprocessed_412_AUDIO_FREQ
# spectrogram_preprocessed_412_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\413_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_413_AUDIO
# spectrogram_cleaned_413_AUDIO_FREQ
# spectrogram_cleaned_413_AUDIO_TIME
# spectrogram_cleaned_preprocessed_413_AUDIO
# spectrogram_preprocessed_413_AUDIO_FREQ
# spectrogram_preprocessed_413_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\414_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_414_AUDIO
# spectrogram_cleaned_414_AUDIO_FREQ
# spectrogram_cleaned_414_AUDIO_TIME
# spectrogram_cleaned_preprocessed_414_AUDIO
# spectrogram_preprocessed_414_AUDIO_FREQ
# spectrogram_preprocessed_414_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\415_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_415_AUDIO
# spectrogram_cleaned_415_AUDIO_FREQ
# spectrogram_cleaned_415_AUDIO_TIME
# spectrogram_cleaned_preprocessed_415_AUDIO
# spectrogram_preprocessed_415_AUDIO_FREQ
# spectrogram_preprocessed_415_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\416_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_416_AUDIO
# spectrogram_cleaned_416_AUDIO_FREQ
# spectrogram_cleaned_416_AUDIO_TIME
# spectrogram_cleaned_preprocessed_416_AUDIO
# spectrogram_preprocessed_416_AUDIO_FREQ
# spectrogram_preprocessed_416_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\417_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_417_AUDIO
# spectrogram_cleaned_417_AUDIO_FREQ
# spectrogram_cleaned_417_AUDIO_TIME
# spectrogram_cleaned_preprocessed_417_AUDIO
# spectrogram_preprocessed_417_AUDIO_FREQ
# spectrogram_preprocessed_417_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\418_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_418_AUDIO
# spectrogram_cleaned_418_AUDIO_FREQ
# spectrogram_cleaned_418_AUDIO_TIME
# spectrogram_cleaned_preprocessed_418_AUDIO
# spectrogram_preprocessed_418_AUDIO_FREQ
# spectrogram_preprocessed_418_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\419_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_419_AUDIO
# spectrogram_cleaned_419_AUDIO_FREQ
# spectrogram_cleaned_419_AUDIO_TIME
# spectrogram_cleaned_preprocessed_419_AUDIO
# spectrogram_preprocessed_419_AUDIO_FREQ
# spectrogram_preprocessed_419_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\420_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_420_AUDIO
# spectrogram_cleaned_420_AUDIO_FREQ
# spectrogram_cleaned_420_AUDIO_TIME
# spectrogram_cleaned_preprocessed_420_AUDIO
# spectrogram_preprocessed_420_AUDIO_FREQ
# spectrogram_preprocessed_420_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\421_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_421_AUDIO
# spectrogram_cleaned_421_AUDIO_FREQ
# spectrogram_cleaned_421_AUDIO_TIME
# spectrogram_cleaned_preprocessed_421_AUDIO
# spectrogram_preprocessed_421_AUDIO_FREQ
# spectrogram_preprocessed_421_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\422_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_422_AUDIO
# spectrogram_cleaned_422_AUDIO_FREQ
# spectrogram_cleaned_422_AUDIO_TIME
# spectrogram_cleaned_preprocessed_422_AUDIO
# spectrogram_preprocessed_422_AUDIO_FREQ
# spectrogram_preprocessed_422_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\423_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_423_AUDIO
# spectrogram_cleaned_423_AUDIO_FREQ
# spectrogram_cleaned_423_AUDIO_TIME
# spectrogram_cleaned_preprocessed_423_AUDIO
# spectrogram_preprocessed_423_AUDIO_FREQ
# spectrogram_preprocessed_423_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\424_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_424_AUDIO
# spectrogram_cleaned_424_AUDIO_FREQ
# spectrogram_cleaned_424_AUDIO_TIME
# spectrogram_cleaned_preprocessed_424_AUDIO
# spectrogram_preprocessed_424_AUDIO_FREQ
# spectrogram_preprocessed_424_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\425_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_425_AUDIO
# spectrogram_cleaned_425_AUDIO_FREQ
# spectrogram_cleaned_425_AUDIO_TIME
# spectrogram_cleaned_preprocessed_425_AUDIO
# spectrogram_preprocessed_425_AUDIO_FREQ
# spectrogram_preprocessed_425_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\426_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_426_AUDIO
# spectrogram_cleaned_426_AUDIO_FREQ
# spectrogram_cleaned_426_AUDIO_TIME
# spectrogram_cleaned_preprocessed_426_AUDIO
# spectrogram_preprocessed_426_AUDIO_FREQ
# spectrogram_preprocessed_426_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\427_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_427_AUDIO
# spectrogram_cleaned_427_AUDIO_FREQ
# spectrogram_cleaned_427_AUDIO_TIME
# spectrogram_cleaned_preprocessed_427_AUDIO
# spectrogram_preprocessed_427_AUDIO_FREQ
# spectrogram_preprocessed_427_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\428_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_428_AUDIO
# spectrogram_cleaned_428_AUDIO_FREQ
# spectrogram_cleaned_428_AUDIO_TIME
# spectrogram_cleaned_preprocessed_428_AUDIO
# spectrogram_preprocessed_428_AUDIO_FREQ
# spectrogram_preprocessed_428_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\429_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_429_AUDIO
# spectrogram_cleaned_429_AUDIO_FREQ
# spectrogram_cleaned_429_AUDIO_TIME
# spectrogram_cleaned_preprocessed_429_AUDIO
# spectrogram_preprocessed_429_AUDIO_FREQ
# spectrogram_preprocessed_429_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\430_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_430_AUDIO
# spectrogram_cleaned_430_AUDIO_FREQ
# spectrogram_cleaned_430_AUDIO_TIME
# spectrogram_cleaned_preprocessed_430_AUDIO
# spectrogram_preprocessed_430_AUDIO_FREQ
# spectrogram_preprocessed_430_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\431_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_431_AUDIO
# spectrogram_cleaned_431_AUDIO_FREQ
# spectrogram_cleaned_431_AUDIO_TIME
# spectrogram_cleaned_preprocessed_431_AUDIO
# spectrogram_preprocessed_431_AUDIO_FREQ
# spectrogram_preprocessed_431_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\432_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_432_AUDIO
# spectrogram_cleaned_432_AUDIO_FREQ
# spectrogram_cleaned_432_AUDIO_TIME
# spectrogram_cleaned_preprocessed_432_AUDIO
# spectrogram_preprocessed_432_AUDIO_FREQ
# spectrogram_preprocessed_432_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\433_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_433_AUDIO
# spectrogram_cleaned_433_AUDIO_FREQ
# spectrogram_cleaned_433_AUDIO_TIME
# spectrogram_cleaned_preprocessed_433_AUDIO
# spectrogram_preprocessed_433_AUDIO_FREQ
# spectrogram_preprocessed_433_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\434_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_434_AUDIO
# spectrogram_cleaned_434_AUDIO_FREQ
# spectrogram_cleaned_434_AUDIO_TIME
# spectrogram_cleaned_preprocessed_434_AUDIO
# spectrogram_preprocessed_434_AUDIO_FREQ
# spectrogram_preprocessed_434_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\435_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_435_AUDIO
# spectrogram_cleaned_435_AUDIO_FREQ
# spectrogram_cleaned_435_AUDIO_TIME
# spectrogram_cleaned_preprocessed_435_AUDIO
# spectrogram_preprocessed_435_AUDIO_FREQ
# spectrogram_preprocessed_435_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\436_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_436_AUDIO
# spectrogram_cleaned_436_AUDIO_FREQ
# spectrogram_cleaned_436_AUDIO_TIME
# spectrogram_cleaned_preprocessed_436_AUDIO
# spectrogram_preprocessed_436_AUDIO_FREQ
# spectrogram_preprocessed_436_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\437_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_437_AUDIO
# spectrogram_cleaned_437_AUDIO_FREQ
# spectrogram_cleaned_437_AUDIO_TIME
# spectrogram_cleaned_preprocessed_437_AUDIO
# spectrogram_preprocessed_437_AUDIO_FREQ
# spectrogram_preprocessed_437_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\438_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_438_AUDIO
# spectrogram_cleaned_438_AUDIO_FREQ
# spectrogram_cleaned_438_AUDIO_TIME
# spectrogram_cleaned_preprocessed_438_AUDIO
# spectrogram_preprocessed_438_AUDIO_FREQ
# spectrogram_preprocessed_438_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\439_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_439_AUDIO
# spectrogram_cleaned_439_AUDIO_FREQ
# spectrogram_cleaned_439_AUDIO_TIME
# spectrogram_cleaned_preprocessed_439_AUDIO
# spectrogram_preprocessed_439_AUDIO_FREQ
# spectrogram_preprocessed_439_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\440_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_440_AUDIO
# spectrogram_cleaned_440_AUDIO_FREQ
# spectrogram_cleaned_440_AUDIO_TIME
# spectrogram_cleaned_preprocessed_440_AUDIO
# spectrogram_preprocessed_440_AUDIO_FREQ
# spectrogram_preprocessed_440_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\441_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_441_AUDIO
# spectrogram_cleaned_441_AUDIO_FREQ
# spectrogram_cleaned_441_AUDIO_TIME
# spectrogram_cleaned_preprocessed_441_AUDIO
# spectrogram_preprocessed_441_AUDIO_FREQ
# spectrogram_preprocessed_441_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\442_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_442_AUDIO
# spectrogram_cleaned_442_AUDIO_FREQ
# spectrogram_cleaned_442_AUDIO_TIME
# spectrogram_cleaned_preprocessed_442_AUDIO
# spectrogram_preprocessed_442_AUDIO_FREQ
# spectrogram_preprocessed_442_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\443_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_443_AUDIO
# spectrogram_cleaned_443_AUDIO_FREQ
# spectrogram_cleaned_443_AUDIO_TIME
# ...
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_445_AUDIO
# spectrogram_cleaned_445_AUDIO_FREQ
# spectrogram_cleaned_445_AUDIO_TIME
# spectrogram_cleaned_preprocessed_445_AUDIO
# spectrogram_preprocessed_445_AUDIO_FREQ
# spectrogram_preprocessed_445_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\446_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_446_AUDIO
# spectrogram_cleaned_446_AUDIO_FREQ
# spectrogram_cleaned_446_AUDIO_TIME
# spectrogram_cleaned_preprocessed_446_AUDIO
# spectrogram_preprocessed_446_AUDIO_FREQ
# spectrogram_preprocessed_446_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\447_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_447_AUDIO
# spectrogram_cleaned_447_AUDIO_FREQ
# spectrogram_cleaned_447_AUDIO_TIME
# spectrogram_cleaned_preprocessed_447_AUDIO
# spectrogram_preprocessed_447_AUDIO_FREQ
# spectrogram_preprocessed_447_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\448_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_448_AUDIO
# spectrogram_cleaned_448_AUDIO_FREQ
# spectrogram_cleaned_448_AUDIO_TIME
# spectrogram_cleaned_preprocessed_448_AUDIO
# spectrogram_preprocessed_448_AUDIO_FREQ
# spectrogram_preprocessed_448_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\449_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_449_AUDIO
# spectrogram_cleaned_449_AUDIO_FREQ
# spectrogram_cleaned_449_AUDIO_TIME
# spectrogram_cleaned_preprocessed_449_AUDIO
# spectrogram_preprocessed_449_AUDIO_FREQ
# spectrogram_preprocessed_449_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\450_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_450_AUDIO
# spectrogram_cleaned_450_AUDIO_FREQ
# spectrogram_cleaned_450_AUDIO_TIME
# spectrogram_cleaned_preprocessed_450_AUDIO
# spectrogram_preprocessed_450_AUDIO_FREQ
# spectrogram_preprocessed_450_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\451_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_451_AUDIO
# spectrogram_cleaned_451_AUDIO_FREQ
# spectrogram_cleaned_451_AUDIO_TIME
# spectrogram_cleaned_preprocessed_451_AUDIO
# spectrogram_preprocessed_451_AUDIO_FREQ
# spectrogram_preprocessed_451_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\452_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_452_AUDIO
# spectrogram_cleaned_452_AUDIO_FREQ
# spectrogram_cleaned_452_AUDIO_TIME
# spectrogram_cleaned_preprocessed_452_AUDIO
# spectrogram_preprocessed_452_AUDIO_FREQ
# spectrogram_preprocessed_452_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\453_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_453_AUDIO
# spectrogram_cleaned_453_AUDIO_FREQ
# spectrogram_cleaned_453_AUDIO_TIME
# spectrogram_cleaned_preprocessed_453_AUDIO
# spectrogram_preprocessed_453_AUDIO_FREQ
# spectrogram_preprocessed_453_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\454_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_454_AUDIO
# spectrogram_cleaned_454_AUDIO_FREQ
# spectrogram_cleaned_454_AUDIO_TIME
# spectrogram_cleaned_preprocessed_454_AUDIO
# spectrogram_preprocessed_454_AUDIO_FREQ
# spectrogram_preprocessed_454_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\455_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_455_AUDIO
# spectrogram_cleaned_455_AUDIO_FREQ
# spectrogram_cleaned_455_AUDIO_TIME
# spectrogram_cleaned_preprocessed_455_AUDIO
# spectrogram_preprocessed_455_AUDIO_FREQ
# spectrogram_preprocessed_455_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\456_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_456_AUDIO
# spectrogram_cleaned_456_AUDIO_FREQ
# spectrogram_cleaned_456_AUDIO_TIME
# spectrogram_cleaned_preprocessed_456_AUDIO
# spectrogram_preprocessed_456_AUDIO_FREQ
# spectrogram_preprocessed_456_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\457_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_457_AUDIO
# spectrogram_cleaned_457_AUDIO_FREQ
# spectrogram_cleaned_457_AUDIO_TIME
# spectrogram_cleaned_preprocessed_457_AUDIO
# spectrogram_preprocessed_457_AUDIO_FREQ
# spectrogram_preprocessed_457_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\458_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_458_AUDIO
# spectrogram_cleaned_458_AUDIO_FREQ
# spectrogram_cleaned_458_AUDIO_TIME
# spectrogram_cleaned_preprocessed_458_AUDIO
# spectrogram_preprocessed_458_AUDIO_FREQ
# spectrogram_preprocessed_458_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\459_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_459_AUDIO
# spectrogram_cleaned_459_AUDIO_FREQ
# spectrogram_cleaned_459_AUDIO_TIME
# spectrogram_cleaned_preprocessed_459_AUDIO
# spectrogram_preprocessed_459_AUDIO_FREQ
# spectrogram_preprocessed_459_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\461_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_461_AUDIO
# spectrogram_cleaned_461_AUDIO_FREQ
# spectrogram_cleaned_461_AUDIO_TIME
# spectrogram_cleaned_preprocessed_461_AUDIO
# spectrogram_preprocessed_461_AUDIO_FREQ
# spectrogram_preprocessed_461_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\462_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_462_AUDIO
# spectrogram_cleaned_462_AUDIO_FREQ
# spectrogram_cleaned_462_AUDIO_TIME
# spectrogram_cleaned_preprocessed_462_AUDIO
# spectrogram_preprocessed_462_AUDIO_FREQ
# spectrogram_preprocessed_462_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\463_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_463_AUDIO
# spectrogram_cleaned_463_AUDIO_FREQ
# spectrogram_cleaned_463_AUDIO_TIME
# spectrogram_cleaned_preprocessed_463_AUDIO
# spectrogram_preprocessed_463_AUDIO_FREQ
# spectrogram_preprocessed_463_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\464_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_464_AUDIO
# spectrogram_cleaned_464_AUDIO_FREQ
# spectrogram_cleaned_464_AUDIO_TIME
# spectrogram_cleaned_preprocessed_464_AUDIO
# spectrogram_preprocessed_464_AUDIO_FREQ
# spectrogram_preprocessed_464_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\465_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_465_AUDIO
# spectrogram_cleaned_465_AUDIO_FREQ
# spectrogram_cleaned_465_AUDIO_TIME
# spectrogram_cleaned_preprocessed_465_AUDIO
# spectrogram_preprocessed_465_AUDIO_FREQ
# spectrogram_preprocessed_465_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\466_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_466_AUDIO
# spectrogram_cleaned_466_AUDIO_FREQ
# spectrogram_cleaned_466_AUDIO_TIME
# spectrogram_cleaned_preprocessed_466_AUDIO
# spectrogram_preprocessed_466_AUDIO_FREQ
# spectrogram_preprocessed_466_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\467_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_467_AUDIO
# spectrogram_cleaned_467_AUDIO_FREQ
# spectrogram_cleaned_467_AUDIO_TIME
# spectrogram_cleaned_preprocessed_467_AUDIO
# spectrogram_preprocessed_467_AUDIO_FREQ
# spectrogram_preprocessed_467_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\468_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_468_AUDIO
# spectrogram_cleaned_468_AUDIO_FREQ
# spectrogram_cleaned_468_AUDIO_TIME
# spectrogram_cleaned_preprocessed_468_AUDIO
# spectrogram_preprocessed_468_AUDIO_FREQ
# spectrogram_preprocessed_468_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\469_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_469_AUDIO
# spectrogram_cleaned_469_AUDIO_FREQ
# spectrogram_cleaned_469_AUDIO_TIME
# spectrogram_cleaned_preprocessed_469_AUDIO
# spectrogram_preprocessed_469_AUDIO_FREQ
# spectrogram_preprocessed_469_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\470_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_470_AUDIO
# spectrogram_cleaned_470_AUDIO_FREQ
# spectrogram_cleaned_470_AUDIO_TIME
# spectrogram_cleaned_preprocessed_470_AUDIO
# spectrogram_preprocessed_470_AUDIO_FREQ
# spectrogram_preprocessed_470_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\471_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_471_AUDIO
# spectrogram_cleaned_471_AUDIO_FREQ
# spectrogram_cleaned_471_AUDIO_TIME
# spectrogram_cleaned_preprocessed_471_AUDIO
# spectrogram_preprocessed_471_AUDIO_FREQ
# spectrogram_preprocessed_471_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\472_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_472_AUDIO
# spectrogram_cleaned_472_AUDIO_FREQ
# spectrogram_cleaned_472_AUDIO_TIME
# spectrogram_cleaned_preprocessed_472_AUDIO
# spectrogram_preprocessed_472_AUDIO_FREQ
# spectrogram_preprocessed_472_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\473_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_473_AUDIO
# spectrogram_cleaned_473_AUDIO_FREQ
# spectrogram_cleaned_473_AUDIO_TIME
# spectrogram_cleaned_preprocessed_473_AUDIO
# spectrogram_preprocessed_473_AUDIO_FREQ
# spectrogram_preprocessed_473_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\474_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_474_AUDIO
# spectrogram_cleaned_474_AUDIO_FREQ
# spectrogram_cleaned_474_AUDIO_TIME
# spectrogram_cleaned_preprocessed_474_AUDIO
# spectrogram_preprocessed_474_AUDIO_FREQ
# spectrogram_preprocessed_474_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\475_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_475_AUDIO
# spectrogram_cleaned_475_AUDIO_FREQ
# spectrogram_cleaned_475_AUDIO_TIME
# spectrogram_cleaned_preprocessed_475_AUDIO
# spectrogram_preprocessed_475_AUDIO_FREQ
# spectrogram_preprocessed_475_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\476_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_476_AUDIO
# spectrogram_cleaned_476_AUDIO_FREQ
# spectrogram_cleaned_476_AUDIO_TIME
# spectrogram_cleaned_preprocessed_476_AUDIO
# spectrogram_preprocessed_476_AUDIO_FREQ
# spectrogram_preprocessed_476_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\477_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_477_AUDIO
# spectrogram_cleaned_477_AUDIO_FREQ
# spectrogram_cleaned_477_AUDIO_TIME
# spectrogram_cleaned_preprocessed_477_AUDIO
# spectrogram_preprocessed_477_AUDIO_FREQ
# spectrogram_preprocessed_477_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\478_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_478_AUDIO
# spectrogram_cleaned_478_AUDIO_FREQ
# spectrogram_cleaned_478_AUDIO_TIME
# spectrogram_cleaned_preprocessed_478_AUDIO
# spectrogram_preprocessed_478_AUDIO_FREQ
# spectrogram_preprocessed_478_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\479_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_479_AUDIO
# spectrogram_cleaned_479_AUDIO_FREQ
# spectrogram_cleaned_479_AUDIO_TIME
# spectrogram_cleaned_preprocessed_479_AUDIO
# spectrogram_preprocessed_479_AUDIO_FREQ
# spectrogram_preprocessed_479_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\480_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_480_AUDIO
# spectrogram_cleaned_480_AUDIO_FREQ
# spectrogram_cleaned_480_AUDIO_TIME
# spectrogram_cleaned_preprocessed_480_AUDIO
# spectrogram_preprocessed_480_AUDIO_FREQ
# spectrogram_preprocessed_480_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\481_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_481_AUDIO
# spectrogram_cleaned_481_AUDIO_FREQ
# spectrogram_cleaned_481_AUDIO_TIME
# spectrogram_cleaned_preprocessed_481_AUDIO
# spectrogram_preprocessed_481_AUDIO_FREQ
# spectrogram_preprocessed_481_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\482_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_482_AUDIO
# spectrogram_cleaned_482_AUDIO_FREQ
# spectrogram_cleaned_482_AUDIO_TIME
# spectrogram_cleaned_preprocessed_482_AUDIO
# spectrogram_preprocessed_482_AUDIO_FREQ
# spectrogram_preprocessed_482_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\483_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_483_AUDIO
# spectrogram_cleaned_483_AUDIO_FREQ
# spectrogram_cleaned_483_AUDIO_TIME
# spectrogram_cleaned_preprocessed_483_AUDIO
# spectrogram_preprocessed_483_AUDIO_FREQ
# spectrogram_preprocessed_483_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\484_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_484_AUDIO
# spectrogram_cleaned_484_AUDIO_FREQ
# spectrogram_cleaned_484_AUDIO_TIME
# spectrogram_cleaned_preprocessed_484_AUDIO
# spectrogram_preprocessed_484_AUDIO_FREQ
# spectrogram_preprocessed_484_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\485_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_485_AUDIO
# spectrogram_cleaned_485_AUDIO_FREQ
# spectrogram_cleaned_485_AUDIO_TIME
# spectrogram_cleaned_preprocessed_485_AUDIO
# spectrogram_preprocessed_485_AUDIO_FREQ
# spectrogram_preprocessed_485_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\486_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_486_AUDIO
# spectrogram_cleaned_486_AUDIO_FREQ
# spectrogram_cleaned_486_AUDIO_TIME
# spectrogram_cleaned_preprocessed_486_AUDIO
# spectrogram_preprocessed_486_AUDIO_FREQ
# spectrogram_preprocessed_486_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\487_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_487_AUDIO
# spectrogram_cleaned_487_AUDIO_FREQ
# spectrogram_cleaned_487_AUDIO_TIME
# spectrogram_cleaned_preprocessed_487_AUDIO
# spectrogram_preprocessed_487_AUDIO_FREQ
# spectrogram_preprocessed_487_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\488_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_488_AUDIO
# spectrogram_cleaned_488_AUDIO_FREQ
# spectrogram_cleaned_488_AUDIO_TIME
# spectrogram_cleaned_preprocessed_488_AUDIO
# spectrogram_preprocessed_488_AUDIO_FREQ
# spectrogram_preprocessed_488_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\489_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_489_AUDIO
# spectrogram_cleaned_489_AUDIO_FREQ
# spectrogram_cleaned_489_AUDIO_TIME
# spectrogram_cleaned_preprocessed_489_AUDIO
# spectrogram_preprocessed_489_AUDIO_FREQ
# spectrogram_preprocessed_489_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\490_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_490_AUDIO
# spectrogram_cleaned_490_AUDIO_FREQ
# spectrogram_cleaned_490_AUDIO_TIME
# spectrogram_cleaned_preprocessed_490_AUDIO
# spectrogram_preprocessed_490_AUDIO_FREQ
# spectrogram_preprocessed_490_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\491_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_491_AUDIO
# spectrogram_cleaned_491_AUDIO_FREQ
# spectrogram_cleaned_491_AUDIO_TIME
# spectrogram_cleaned_preprocessed_491_AUDIO
# spectrogram_preprocessed_491_AUDIO_FREQ
# spectrogram_preprocessed_491_AUDIO_TIME
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\492_P
# d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\316_P
# spectrogram_cleaned_492_AUDIO
# spectrogram_cleaned_492_AUDIO_FREQ
# spectrogram_cleaned_492_AUDIO_TIME
# spectrogram_cleaned_preprocessed_492_AUDIO
# spectrogram_preprocessed_492_AUDIO_FREQ
# spectrogram_preprocessed_492_AUDIO_TIME
