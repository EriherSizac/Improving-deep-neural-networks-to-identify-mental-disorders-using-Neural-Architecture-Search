# %%
import os
import glob
root_path = "d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data"
for folder_name in os.listdir(root_path):
    folder_path = os.path.join(root_path, folder_name)
    if os.path.isdir(folder_path):

        # Delete preprocessed files before processing
        for preprocessed_file in glob.glob(os.path.join(folder_path, 'preprocessed_*.wav')):
            os.remove(preprocessed_file)
            print(f'Deleted preprocessed file: {preprocessed_file}')
# Out:
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\300_P\preprocessed_300_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\301_P\preprocessed_301_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\302_P\preprocessed_302_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\303_P\preprocessed_303_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\304_P\preprocessed_304_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\305_P\preprocessed_305_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\306_P\preprocessed_306_AUDIO.wav
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\307_P\preprocessed_307_AUDIO.wav
# ...

# %%
import os
import glob
root_path = "d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data"
for folder_name in os.listdir(root_path):
    folder_path = os.path.join(root_path, folder_name)
    if os.path.isdir(folder_path):

        # Delete preprocessed files before processing
        for preprocessed_file in glob.glob(os.path.join(folder_path, 'spectrogram*.jpg')):
            os.remove(preprocessed_file)
            print(f'Deleted preprocessed file: {preprocessed_file}')
            
        for preprocessed_file in glob.glob(os.path.join(folder_path, 'resized*.jpg')):
            os.remove(preprocessed_file)
            print(f'Deleted preprocessed file: {preprocessed_file}')
# Out:
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\300_P\spectrogram_preprocessed_300_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\300_P\resized_spectrogram_preprocessed_300_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\301_P\spectrogram_preprocessed_301_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\301_P\resized_spectrogram_preprocessed_301_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\302_P\spectrogram_preprocessed_302_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\302_P\resized_spectrogram_preprocessed_302_AUDIO.jpg
# Deleted preprocessed file: d:\Sistema\Escritorio\Escritorio\Tesis\DAIC-WOZ\data\303_P\spectrogram_preprocessed_303_AUDIO.jpg
# ...
