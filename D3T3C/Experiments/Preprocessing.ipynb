# %% [markdown]
# # Imports

# %%
# Global imports
import os
import numpy as np
import pandas as pd
import imageio.v2 as imageio
import tensorflow as tf
import tensorflow_addons as tfa
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import glob
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import BatchNormalization, Conv2D, LeakyReLU, MaxPooling2D, Flatten, Dense
import torchaudio

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Loading the data

# %% [markdown]
# ## Global data

# %% [markdown]
# We first load the CSV file with the data of all participants, then we will use it to make a wider dataset with all the recordings

# %%
df = pd.read_csv('D:\Github\Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search\D3T3C\D3TEC Dataset\Dataset.csv')
df.head()
# Out:
#                     Marca temporal  Participant_ID  PHQ-9 Score  Age  Gender  \
# 0  2023/10/11 11:13:07 a. m. GMT-6               1            8   36  Female
# 1   2023/10/11 1:13:47 p. m. GMT-6               2            1   57  Female
# 2   2023/10/11 1:57:08 p. m. GMT-6               3            3   62  Female
# 3   2023/10/11 3:02:28 p. m. GMT-6               4           13   48  Female
# 4   2023/10/11 4:11:32 p. m. GMT-6               5            7   40  Female
#
#           Lugar de Residencia Lugar de Procedencia   Social Class Institution  \
# 0  Santa Catarina, Nuevo León                  NaN  Working Class       CAABI
# 1  Santa Catarina, Nuevo León                  NaN  Working Class       CAABI
# 2       San Pedro, Nuevo León                  NaN    Upper Class       CAABI
# 3  Santa Catarina, Nuevo León                  NaN  Working Class       CAABI
# 4  Santa Catarina, Nuevo León                  NaN   Middle Class       CAABI
#
#                   Medicine      Physical Condition Mental Health Condition  \
# 0  Forxiga. Atrovastatina.  Diabetes. Fatty Liver.                     NaN
# 1               Metformina                     NaN                     NaN
# 2              Sertrialina       Estenosis Espinal                Ansiedad
# 3                      NaN                     NaN                     NaN
# 4              Homeopatía.                     NaN       Moderate Anxiety.
#
#   Depression Diagnosis (level)
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %% [markdown]
# ### Checking types

# %%
df.dtypes
# Out:
# Marca temporal                  object
# Participant_ID                   int64
# PHQ-9 Score                      int64
# Age                              int64
# Gender                          object
# Lugar de Residencia             object
# Lugar de Procedencia            object
# Social Class                    object
# Institution                     object
# Medicine                        object
# Physical Condition              object
# Mental Health Condition         object
# Depression Diagnosis (level)    object
# dtype: object

# %% [markdown]
# ### Adding binary classification

# %%
# Crear la nueva columna "PHQ-Binary" basada en "PHQ-9 Score"
df['PHQ-Binary'] = df['PHQ-9 Score'].apply(lambda x: 1 if x >= 10 else 0)
df
# Out:
#                      Marca temporal  Participant_ID  PHQ-9 Score  Age  Gender  \
# 0   2023/10/11 11:13:07 a. m. GMT-6               1            8   36  Female
# 1    2023/10/11 1:13:47 p. m. GMT-6               2            1   57  Female
# 2    2023/10/11 1:57:08 p. m. GMT-6               3            3   62  Female
# 3    2023/10/11 3:02:28 p. m. GMT-6               4           13   48  Female
# 4    2023/10/11 4:11:32 p. m. GMT-6               5            7   40  Female
# ..                              ...             ...          ...  ...     ...
# 57   2024/04/09 5:28:51 p. m. GMT-6             149           12   19    Male
# 58   2024/04/10 4:17:26 p. m. GMT-6             150           12   20  Female
# 59   2024/04/10 4:18:06 p. m. GMT-6             151            4   20    Male
# 60   2024/04/10 4:18:50 p. m. GMT-6             152            5   22    Male
# 61   2024/04/10 5:32:39 p. m. GMT-6             153           19   20    Male
#
#            Lugar de Residencia    Lugar de Procedencia   Social Class  \
# 0   Santa Catarina, Nuevo León                     NaN  Working Class
# 1   Santa Catarina, Nuevo León                     NaN  Working Class
# 2        San Pedro, Nuevo León                     NaN    Upper Class
# 3   Santa Catarina, Nuevo León                     NaN  Working Class
# 4   Santa Catarina, Nuevo León                     NaN   Middle Class
# ..                         ...                     ...            ...
# 57      Monterrey, Nuevo León.       Bogotá, Colombia.    Upper Class
# 58      Monterrey, Nuevo León.         San Luis Potosí   Middle Class
# 59      Monterrey, Nuevo León.  Monterrey, Nuevo León.    Upper Class
# 60      Monterrey, Nuevo León.        Oaxaca de Juárez    Upper Class
# 61      Monterrey, Nuevo León.                    CDMX   Middle Class
#
#    Institution                 Medicine      Physical Condition  \
# 0        CAABI  Forxiga. Atrovastatina.  Diabetes. Fatty Liver.
# 1        CAABI               Metformina                     NaN
# 2        CAABI              Sertrialina       Estenosis Espinal
# 3        CAABI                      NaN                     NaN
# 4        CAABI              Homeopatía.                     NaN
# ..         ...                      ...                     ...
# 57         TEC                      NaN                     NaN
# 58         TEC                      NaN                     NaN
# 59         TEC                      NaN                     NaN
# 60         TEC                      NaN                     NaN
# 61         TEC                      NaN                     NaN
#
#    Mental Health Condition Depression Diagnosis (level)  PHQ-Binary
# 0                      NaN                          NaN           0
# 1                      NaN                          NaN           0
# 2                 Ansiedad                          NaN           0
# 3                      NaN                          NaN           1
# 4        Moderate Anxiety.                          NaN           0
# ..                     ...                          ...         ...
# 57                     NaN                          NaN           1
# 58                     NaN                          NaN           1
# 59                     NaN                          NaN           0
# 60                     NaN                          NaN           0
# 61                     NaN                          NaN           1
#
# [62 rows x 14 columns]

# %% [markdown]
# ### Treat data frame as dict

# %%
df_dict = df.set_index('Participant_ID').to_dict('index')
df_dict
# Out:
# {1: {'Marca temporal': '2023/10/11 11:13:07 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 8,
#   'Age': 36,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Forxiga. Atrovastatina.',
#   'Physical Condition': 'Diabetes. Fatty Liver.',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  2: {'Marca temporal': '2023/10/11 1:13:47 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 1,
#   'Age': 57,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Metformina',
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  3: {'Marca temporal': '2023/10/11 1:57:08 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 3,
#   'Age': 62,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'San Pedro, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Upper Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Sertrialina',
#   'Physical Condition': 'Estenosis Espinal',
#   'Mental Health Condition': 'Ansiedad',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  4: {'Marca temporal': '2023/10/11 3:02:28 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 13,
#   'Age': 48,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  5: {'Marca temporal': '2023/10/11 4:11:32 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 7,
#   'Age': 40,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Middle Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Homeopatía.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Moderate Anxiety.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  6: {'Marca temporal': '2023/10/11 4:59:11 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 8,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Middle Class',
#   'Institution': 'CAABI',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Ataques de pánico. Ansiedad',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  8: {'Marca temporal': '2023/10/18 4:11:01 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 12,
#   'Age': 49,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Middle Class',
#   'Institution': 'CAABI',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  9: {'Marca temporal': '2023/10/18 4:52:50 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 21,
#   'Age': 41,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Ansiedad',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  100: {'Marca temporal': '2023/11/14 11:30:27 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 4,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Nuevo León',
#   'Lugar de Procedencia': 'Estado de México',
#   'Social Class': 'Working Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'No. (preguntar a Gaby Nava)',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  101: {'Marca temporal': '2023/11/14 6:20:05 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 16,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Guadalajara',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Escitalopram',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  102: {'Marca temporal': '2023/11/14 6:21:23 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 6,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León',
#   'Social Class': 'Working Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión (pero hace dos años)',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  103: {'Marca temporal': '2023/11/14 6:23:43 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 15,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'CDMX',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  105: {'Marca temporal': '2023/11/14 6:25:23 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 6,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Michoacán',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  104: {'Marca temporal': '2023/11/14 6:26:44 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 6,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Saltillo, Coahuila',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  106: {'Marca temporal': '2023/11/15 1:40:44 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 24,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Lima, Perú',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Fluoxetina, Quetiapina, Alprazolam',
#   'Physical Condition': 'Síndrome del Túnel Carpiano',
#   'Mental Health Condition': 'Depresión, ansiedad crónica, ansiedad social, fobia social.',
#   'Depression Diagnosis (level)': 'Severe',
#   'PHQ-Binary': 1},
#  107: {'Marca temporal': '2023/11/22 10:23:03 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'San Pedro Sula, Honduras',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': 'Asma',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  108: {'Marca temporal': '2023/11/22 11:12:04 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 14,
#   'Age': 24,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión. Ansiedad.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  109: {'Marca temporal': '2023/11/22 11:42:15 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 20,
#   'Age': 22,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Veracruz',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Bupropion, valzoprato de magnesio. Y un medicamento anti-psicótico (no recuerda el nombre)',
#   'Physical Condition': 'Quiste en el cerebro.',
#   'Mental Health Condition': 'Depresión mayor con rasgos psicóticos.',
#   'Depression Diagnosis (level)': 'Severe',
#   'PHQ-Binary': 1},
#  110: {'Marca temporal': '2023/11/22 12:33:21 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Rio Bravo, Tamaulipas',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión (hace un año)',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  111: {'Marca temporal': '2023/11/24 1:27:23 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 16,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Saltillo, Coahuila',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'Fluoxetina. Tradea. Clorazepam (30min antes de grabar)',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'TOC. TDAH. Ansiedad',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  112: {'Marca temporal': '2023/11/24 1:30:45 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 18,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Villahermosa, Tabasco.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'Bupropion (300mg). Sertralina(100mg). Lamotrigina(50mg).',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión. Ansiedad. Trastorno Límite de la Personalidad. ',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  113: {'Marca temporal': '2023/11/24 1:32:16 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 12,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Matamoros, Tamaulipas',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Sertralina. Concerta.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'TDA. Ansiedad Generalizada.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  114: {'Marca temporal': '2023/11/24 1:34:53 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 23,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Apodaca, Nuevo León.',
#   'Lugar de Procedencia': 'Chilpancingo, Guerrero.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Citalopram. Clonazepram.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Trastorno depresivo moderado. Trastorno de pánico.',
#   'Depression Diagnosis (level)': 'Moderate',
#   'PHQ-Binary': 1},
#  115: {'Marca temporal': '2023/11/24 1:36:41 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 2,
#   'Age': 23,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Puebla, Puebla.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  116: {'Marca temporal': '2023/11/24 1:37:34 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 1,
#   'Age': 23,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Villahermosa, Tabasco.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  118: {'Marca temporal': '2023/11/28 12:05:35 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 8,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'Atlacomulco, Estado de México',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  117: {'Marca temporal': '2023/11/28 12:49:57 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 7,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Culiacán, Sinaloa',
#   'Social Class': 'No Answer',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  119: {'Marca temporal': '2023/11/28 12:50:57 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 1,
#   'Age': 18,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Puebla, Puebla.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  120: {'Marca temporal': '2023/11/28 12:51:57 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 12,
#   'Age': 22,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Culiacán, Sinaloa.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Sertralina.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión. Ansiedad Social.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  121: {'Marca temporal': '2023/12/04 1:20:16 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 13,
#   'Age': 24,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Toluca, Estado de México.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Concerta (18mg). Sertralina (50mg)',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'TDAH. Ansiedad Social. ',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  122: {'Marca temporal': '2024/02/27 12:07:08 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 15,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'San Pedro, Nuevo León',
#   'Lugar de Procedencia': 'San Pedro, Nuevo León',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  123: {'Marca temporal': '2024/03/12 9:30:34 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 10,
#   'Age': 19,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Reynosa, Tamaulipas',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': 'Fibromialgia',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  124: {'Marca temporal': '2024/03/12 9:31:44 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 11,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León',
#   'Lugar de Procedencia': 'San Salvador, El Salvador.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  125: {'Marca temporal': '2024/03/12 9:32:59 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 10,
#   'Age': 23,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León.',
#   'Lugar de Procedencia': 'Torreón, Coahuila.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  126: {'Marca temporal': '2024/03/12 10:03:34 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 2,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'San Pedro Garza García, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  127: {'Marca temporal': '2024/03/12 10:47:46 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 9,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'San Pedro Sula, Honduras.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  128: {'Marca temporal': '2024/03/12 11:19:32 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 11,
#   'Age': 22,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Ciudad de México, CDMX.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'ilimit',
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  129: {'Marca temporal': '2024/03/12 11:38:39 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 2,
#   'Age': 19,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  130: {'Marca temporal': '2024/04/01 7:46:34 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Tijuana, Baja California.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'Metformin, Spironolactone, Myo-Inositol, Diane (ciproterona, etinilestradiol))',
#   'Physical Condition': 'Síndrome de Ovario Poliquístico',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  131: {'Marca temporal': '2024/04/01 7:47:36 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 13,
#   'Age': 19,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Chiapas',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  134: {'Marca temporal': '2024/04/01 7:49:13 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 6,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Houston, TX, USA.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  133: {'Marca temporal': '2024/04/01 7:50:09 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 11,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Chiapas.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  135: {'Marca temporal': '2024/04/01 7:50:50 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 9,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  136: {'Marca temporal': '2024/04/01 7:51:38 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 19,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Chiapas.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Trastorno Depresivo Persistente.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  132: {'Marca temporal': '2024/04/01 7:55:30 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 20,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión Severa. Ansiedad Severa. TOC.',
#   'Depression Diagnosis (level)': 'Severe',
#   'PHQ-Binary': 1},
#  137: {'Marca temporal': '2024/04/03 6:11:47 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 10,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Oaxaca de Juarez, Oaxaca.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depression Symptoms.',
#   'Depression Diagnosis (level)': 'Mild',
#   'PHQ-Binary': 1},
#  138: {'Marca temporal': '2024/04/03 6:12:40 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 14,
#   'Age': 19,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Working Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depression.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  139: {'Marca temporal': '2024/04/03 6:13:41 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 8,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'Tafil. Atiran.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'TAG. Insomnio.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  140: {'Marca temporal': '2024/04/03 6:14:32 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 4,
#   'Age': 21,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Guayaquil, Ecuador.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  141: {'Marca temporal': '2024/04/03 6:15:18 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 2,
#   'Age': 19,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Zacatecas.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': 'Venlafaxina.',
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Depresión.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  142: {'Marca temporal': '2024/04/03 6:16:12 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 4,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Hidalgo.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': 'Duphaston.',
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  143: {'Marca temporal': '2024/04/03 6:17:10 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 11,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Xalapa, Veracruz.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': 'Ataques de Ansiedad.',
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  144: {'Marca temporal': '2024/04/03 6:17:51 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 3,
#   'Age': 22,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Ciudad de Mexico.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': 'SOP',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  145: {'Marca temporal': '2024/04/03 6:18:34 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 21,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Chihuaha',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  146: {'Marca temporal': '2024/04/03 6:19:10 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 10,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Quito, Ecuador.',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  147: {'Marca temporal': '2024/04/09 5:27:36 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 3,
#   'Age': 23,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  148: {'Marca temporal': '2024/04/09 5:28:09 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 18,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  149: {'Marca temporal': '2024/04/09 5:28:51 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 12,
#   'Age': 19,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Bogotá, Colombia.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  150: {'Marca temporal': '2024/04/10 4:17:26 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 12,
#   'Age': 20,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'San Luis Potosí',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1},
#  151: {'Marca temporal': '2024/04/10 4:18:06 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 4,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Monterrey, Nuevo León.',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  152: {'Marca temporal': '2024/04/10 4:18:50 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 5,
#   'Age': 22,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'Oaxaca de Juárez',
#   'Social Class': 'Upper Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0},
#  153: {'Marca temporal': '2024/04/10 5:32:39 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 19,
#   'Age': 20,
#   'Gender': 'Male',
#   'Lugar de Residencia': 'Monterrey, Nuevo León.',
#   'Lugar de Procedencia': 'CDMX',
#   'Social Class': 'Middle Class',
#   'Institution': 'TEC',
#   'Medicine': nan,
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 1}}

# %% [markdown]
# ### Helper function definition

# %% [markdown]
# #### Spectrogram generator

# %%
import torchaudio
import torchaudio.transforms as T

def generate_mel_spectrogram(file_path, n_mels=128, n_fft=2048, hop_length=512):
    """
    Generate a mel spectrogram from an audio file.

    Args:
    - file_path (str): Path to the audio file.
    - n_mels (int): Number of mel filterbanks. Default is 128.
    - n_fft (int): Number of FFT components. Default is 2048.
    - hop_length (int): Length between successive frames. Default is 512.

    Returns:
    - mel_spectrogram (Tensor): The mel spectrogram.
    """
    # Load the audio file
    waveform, sample_rate = torchaudio.load(file_path)

    # Create a Mel Spectrogram Transform
    mel_spectrogram_transform = T.MelSpectrogram(
        sample_rate=sample_rate,
        n_fft=n_fft,
        hop_length=hop_length,
        n_mels=n_mels
    )

    # Apply the transform to get the mel spectrogram
    mel_spectrogram = mel_spectrogram_transform(waveform)

    return mel_spectrogram

# %%
# Map of valence according to the protocol questions
valence_map = {
    'positive': [0, 1, 2, 3, 4, 15, 18, 21],
    'neutral': [5, 6, 7, 8, 9, 16, 19, 22],
    'negative': [10, 11, 12, 13, 14, 17, 20, 23]
}

def load_audios(data_dict, base_path, audio_type):
    """
    Load audios for each participant according to the protocol and add them to the dictionary structure.
    
    Args:
    - data_dict (dict): Dictionary with the participants' information.
    - base_path (str): Base path where participants' audios are located.
    - audio_type (str): Type of audio ('sm' or 'mobile').
    
    Returns:
    - data_dict (dict): Updated dictionary with the loaded audios.
    """
    
    for participant_id, info in data_dict.items():
        # Create the structure for the audios
        info['audios'] = {
            'sm': {'positive': [], 'negative': [], 'neutral': []}
        }
        if audio_type not in info['audios']:
            info['audios'][audio_type] = {}
        
        # Path to the participant's audio folder
        #participant_audio_path = os.path.join(base_path, f'{participant_id:03d}')
        
        # Check if the folder exists
        # if not os.path.exists(participant_audio_path):
        #    print(f'Folder not found: {participant_audio_path}')
        #    continue
        
        # Load audios according to the protocol
        audio_files = os.listdir(base_path)
        for file in audio_files:
            if file == '.DS_Store':
                continue
            file_path = os.path.join(base_path, file)
            # Extract the question number from the file name
            if '_' in file:
                parts = file.split('_')
                if len(parts) == 2:
                    try:
                        question_number = int(parts[1].split('.')[0])
                    except:
                        question_number = int(parts[0].split('.')[0])
                elif len(parts) == 3:
                    question_number = int(parts[2].split('.')[0])
                else:
                    question_number = 0
            else:
                question_number = 0
            
            # Load the audio using torchaudio
            waveform, sample_rate = torchaudio.load(file_path)
            info['audios'][audio_type][question_number] = {
                'file_path': file_path,
                'waveform': waveform,
                'sample_rate': sample_rate
            }
            
            # Determine the valence according to the question number
            # Uncomment for valence classification
            """
            if question_number in valence_map['positive']:
                if 'positive' not in info['audios'][audio_type]:
                    info['audios'][audio_type]['positive'] = []
                info['audios'][audio_type]['positive'].append(file_path)
            elif question_number in valence_map['negative']:
                if 'negative' not in info['audios'][audio_type]:
                    info['audios'][audio_type]['negative'] = []
                info['audios'][audio_type]['negative'].append(file_path)
            elif question_number in valence_map['neutral']:
                if 'neutral' not in info['audios'][audio_type]:
                    info['audios'][audio_type]['neutral'] = []
                info['audios'][audio_type]['neutral'].append(file_path)
            """

    return data_dict


base_path_sm = 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/SM-27'
base_path_mobile = 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020'

data_dict_updated = load_audios(df_dict, base_path_sm, 'sm')
print('---------------------')
data_dict_updated = load_audios(data_dict_updated, base_path_mobile, 'mobile')

# Verify the content of the updated dictionary
data_dict_updated
# Out:
# ---------------------
# {1: {'Marca temporal': '2023/10/11 11:13:07 a.\xa0m. GMT-6',
#   'PHQ-9 Score': 8,
#   'Age': 36,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Forxiga. Atrovastatina.',
#   'Physical Condition': 'Diabetes. Fatty Liver.',
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0,
#   'audios': {'sm': {'positive': [], 'negative': [], 'neutral': []},
#    'mobile': {1: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_1.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.6226e-06, -5.7220e-06,  ...,  1.0014e-05,
#                6.3181e-06,  3.0994e-06]]),
#      'sample_rate': 44100},
#     10: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_10.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.0994e-06, -5.1260e-06,  ..., -1.4305e-06,
#               -2.2650e-06, -1.5497e-06]]),
#      'sample_rate': 44100},
#     11: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_11.wav',
#      'waveform': tensor([[0.0000e+00, 9.5367e-06, 1.8239e-05,  ..., 3.9339e-06, 2.3842e-06,
#               1.0729e-06]]),
#      'sample_rate': 44100},
#     12: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_12.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.5763e-07,  5.9605e-07,  ..., -7.1526e-07,
#               -8.3447e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     13: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_13.wav',
#      'waveform': tensor([[ 0.0000e+00,  0.0000e+00, -9.5367e-07,  ..., -5.9605e-07,
#               -5.9605e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     14: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_14.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.0994e-06,  7.5102e-06,  ..., -1.2398e-05,
#               -8.5831e-06, -4.4107e-06]]),
#      'sample_rate': 44100},
#     15: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_15.wav',
#      'waveform': tensor([[0.0000e+00, 1.2875e-05, 2.2054e-05,  ..., 1.6689e-06, 1.3113e-06,
#               7.1526e-07]]),
#      'sample_rate': 44100},
#     16: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_16.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.9802e-06, -5.9605e-06,  ..., -6.5565e-06,
#               -5.6028e-06, -3.6955e-06]]),
#      'sample_rate': 44100},
#     17: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_17.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.2902e-05,  6.4611e-05,  ..., -1.0729e-05,
#               -7.2718e-06, -3.4571e-06]]),
#      'sample_rate': 44100},
#     18: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_18.wav',
#      'waveform': tensor([[ 0.0000e+00, -8.4639e-06, -1.8716e-05,  ...,  1.1921e-06,
#                7.1526e-07,  4.7684e-07]]),
#      'sample_rate': 44100},
#     19: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_19.wav',
#      'waveform': tensor([[0.0000e+00, 2.9206e-05, 5.9128e-05,  ..., 3.4571e-06, 1.9073e-06,
#               4.7684e-07]]),
#      'sample_rate': 44100},
#     2: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_2.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.9870e-06, -1.5855e-05,  ..., -1.7881e-06,
#               -1.9073e-06, -1.1921e-06]]),
#      'sample_rate': 44100},
#     20: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_20.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-07,  1.4305e-06,  ..., -3.0994e-06,
#               -1.9073e-06, -1.1921e-06]]),
#      'sample_rate': 44100},
#     21: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_21.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.8678e-06, -1.6928e-05,  ..., -1.2636e-05,
#               -8.2254e-06, -4.0531e-06]]),
#      'sample_rate': 44100},
#     22: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_22.wav',
#      'waveform': tensor([[ 0.0000e+00, -6.4373e-06, -1.1563e-05,  ...,  0.0000e+00,
#               -2.3842e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     23: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_23.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.8147e-06, -7.1526e-06,  ..., -9.5367e-07,
#               -1.0729e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     24: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_24.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.1526e-07, -1.7881e-06,  ..., -1.6689e-05,
#               -1.1206e-05, -5.6028e-06]]),
#      'sample_rate': 44100},
#     25: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_25.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.0490e-05, -2.0981e-05,  ..., -2.6226e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     26: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_26.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.8954e-05,  3.8505e-05,  ..., -1.9670e-05,
#               -1.2875e-05, -6.5565e-06]]),
#      'sample_rate': 44100},
#     3: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_3.wav',
#      'waveform': tensor([[0.0000e+00, 5.6028e-06, 1.1563e-05,  ..., 1.1921e-07, 3.5763e-07,
#               1.1921e-07]]),
#      'sample_rate': 44100},
#     4: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_4.wav',
#      'waveform': tensor([[0.0000e+00, 7.6294e-06, 1.5616e-05,  ..., 1.1921e-06, 4.7684e-07,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     5: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_5.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.4544e-05,  2.9683e-05,  ..., -8.5831e-06,
#               -5.8413e-06, -3.3379e-06]]),
#      'sample_rate': 44100},
#     6: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_6.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.7684e-07, -2.1458e-06,  ...,  4.6492e-06,
#                3.6955e-06,  2.7418e-06]]),
#      'sample_rate': 44100},
#     7: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_7.wav',
#      'waveform': tensor([[0.0000e+00, 2.1458e-06, 5.6028e-06,  ..., 6.0797e-06, 4.1723e-06,
#               2.0266e-06]]),
#      'sample_rate': 44100},
#     8: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_8.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.9870e-06, -1.7047e-05,  ..., -1.7166e-05,
#               -1.3709e-05, -9.4175e-06]]),
#      'sample_rate': 44100},
#     9: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_9.wav',
#      'waveform': tensor([[ 0.0000e+00,  5.6028e-06,  1.1683e-05,  ..., -8.9407e-06,
#               -6.6757e-06, -3.5763e-06]]),
#      'sample_rate': 44100},
#     100: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\100_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.6226e-06, -5.0068e-06,  ..., -8.3447e-07,
#               -4.7684e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     101: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\101_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.0531e-06, -7.6294e-06,  ...,  1.0729e-06,
#                2.3842e-07,  1.1921e-07]]),
#      'sample_rate': 44100},
#     102: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\102_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.6689e-06, -3.5763e-06,  ..., -1.1921e-06,
#               -9.5367e-07, -5.9605e-07]]),
#      'sample_rate': 44100},
#     103: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\103_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.6492e-06, -1.0371e-05,  ..., -2.3842e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     104: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\104_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.6689e-06, 3.0994e-06,  ..., 5.9605e-07, 2.3842e-07,
#               1.1921e-07]]),
#      'sample_rate': 44100},
#     105: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\105_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-07, -2.3842e-07,  ...,  4.7684e-07,
#                1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     106: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\106_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -5.3644e-06,  ..., -1.1921e-06,
#               -9.5367e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     107: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\107_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.5034e-06,  5.7220e-06,  ..., -1.1921e-07,
#               -2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     108: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\108_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.0994e-06, -6.4373e-06,  ..., -7.5102e-06,
#               -5.4836e-06, -3.4571e-06]]),
#      'sample_rate': 44100},
#     109: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\109_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.1526e-07, -2.5034e-06,  ...,  1.6689e-06,
#                9.5367e-07,  3.5763e-07]]),
#      'sample_rate': 44100},
#     110: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\110_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.4571e-06,  6.6757e-06,  ...,  4.7684e-07,
#                0.0000e+00, -1.1921e-07]]),
#      'sample_rate': 44100},
#     111: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\111_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.5763e-07,  4.7684e-07,  ...,  2.0266e-06,
#                1.3113e-06,  5.9605e-07]]),
#      'sample_rate': 44100},
#     112: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\112_cel.wav',
#      'waveform': tensor([[0.0000e+00, 5.2452e-06, 9.6560e-06,  ..., 6.9141e-06, 4.5300e-06,
#               2.0266e-06]]),
#      'sample_rate': 44100},
#     113: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\113_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  5.7220e-06,  ..., -3.5763e-06,
#               -2.2650e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     114: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\114_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.6689e-06,  2.6226e-06,  ..., -1.3113e-06,
#               -5.9605e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     115: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\115_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  8.3447e-07,  2.0266e-06,  ..., -6.3181e-06,
#               -3.8147e-06, -1.3113e-06]]),
#      'sample_rate': 44100},
#     116: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\116_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-06, -2.3842e-06,  ...,  3.9339e-06,
#                2.8610e-06,  1.4305e-06]]),
#      'sample_rate': 44100},
#     117: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\117_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  3.8147e-06,  ..., -2.1458e-06,
#               -1.3113e-06, -7.1526e-07]]),
#      'sample_rate': 44100},
#     118: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\118_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.4305e-06,  1.1921e-06,  ..., -2.2650e-06,
#               -4.7684e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     119: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\119_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  9.5367e-07,  1.7881e-06,  ..., -7.1526e-07,
#               -5.9605e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     120: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\120_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  4.8876e-06,  1.0371e-05,  ..., -9.5367e-07,
#               -4.7684e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     121: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\121_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  4.4107e-06,  ..., -9.5367e-07,
#               -8.3447e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     122: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\122_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-06,  3.2187e-06,  ..., -4.7684e-07,
#               -3.5763e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     123: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\123_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.4305e-06, -5.1260e-06,  ..., -4.7684e-07,
#               -1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     124: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\124_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -3.3379e-06,  ..., -2.9802e-06,
#               -2.0266e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     125: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\125_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.0729e-06,  2.1458e-06,  ..., -6.9141e-06,
#               -4.8876e-06, -2.5034e-06]]),
#      'sample_rate': 44100},
#     126: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\126_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.9073e-06, 4.0531e-06,  ..., 0.0000e+00, 0.0000e+00,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     127: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\127_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  5.0068e-06,  ...,  8.3447e-07,
#                2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     128: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\128_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  7.2718e-06,  9.6560e-06,  ..., -4.7684e-07,
#                0.0000e+00,  1.1921e-07]]),
#      'sample_rate': 44100},
#     129: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\129_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.9073e-06,  3.8147e-06,  ..., -5.8413e-06,
#               -4.1723e-06, -2.0266e-06]]),
#      'sample_rate': 44100},
#     130: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\130_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  4.7684e-07,  ..., -3.4571e-06,
#               -2.3842e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     131: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\131_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -6.1989e-06, -1.2994e-05,  ...,  4.1723e-06,
#                2.9802e-06,  1.5497e-06]]),
#      'sample_rate': 44100},
#     132: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\132_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  1.1921e-07,  ..., -2.3842e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     133: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\133_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.0133e-05, 2.0146e-05,  ..., 5.7220e-06, 3.6955e-06,
#               1.6689e-06]]),
#      'sample_rate': 44100},
#     134: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\134_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -5.6028e-06, -1.2279e-05,  ..., -1.2994e-05,
#               -9.1791e-06, -5.0068e-06]]),
#      'sample_rate': 44100},
#     135: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\135_cel.wav',
#      'waveform': tensor([[0.0000e+00, 2.0266e-06, 3.2187e-06,  ..., 1.1206e-05, 7.7486e-06,
#               3.8147e-06]]),
#      'sample_rate': 44100},
#     136: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\136_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.0797e-06, 1.2159e-05,  ..., 2.2650e-06, 2.1458e-06,
#               1.6689e-06]]),
#      'sample_rate': 44100},
#     137: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\137_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.0014e-05, -2.0504e-05,  ..., -1.0848e-05,
#               -7.5102e-06, -3.6955e-06]]),
#      'sample_rate': 44100},
#     138: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\138_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.6955e-06, -3.6955e-06,  ..., -2.7418e-06,
#               -1.6689e-06, -7.1526e-07]]),
#      'sample_rate': 44100},
#     139: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\139_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.8876e-06, -9.8944e-06,  ...,  3.0994e-06,
#                2.0266e-06,  9.5367e-07]]),
#      'sample_rate': 44100},
#     140: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\140_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.5034e-06, -4.7684e-07,  ...,  1.1921e-07,
#                1.1921e-07,  2.3842e-07]]),
#      'sample_rate': 44100},
#     141: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\141_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.1458e-06, -6.5565e-06,  ..., -2.3842e-07,
#               -2.3842e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     142: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\142_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.3181e-06, 1.0490e-05,  ..., 2.5034e-06, 1.7881e-06,
#               8.3447e-07]]),
#      'sample_rate': 44100},
#     143: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\143_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.7881e-06,  4.1723e-06,  ..., -5.7220e-06,
#               -4.1723e-06, -2.0266e-06]]),
#      'sample_rate': 44100},
#     144: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\144_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.9339e-06, -7.7486e-06,  ...,  5.9605e-07,
#                4.7684e-07,  2.3842e-07]]),
#      'sample_rate': 44100},
#     145: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\145_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.6226e-06,  4.1723e-06,  ..., -4.1723e-06,
#               -2.7418e-06, -1.4305e-06]]),
#      'sample_rate': 44100},
#     146: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\146_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.3113e-06, 2.5034e-06,  ..., 1.1921e-07, 4.7684e-07,
#               3.5763e-07]]),
#      'sample_rate': 44100},
#     147: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\147_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.3113e-06, 2.9802e-06,  ..., 1.0729e-06, 1.1921e-07,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     148: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\148_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.3379e-05, -6.7115e-05,  ..., -1.4663e-05,
#               -9.8944e-06, -4.7684e-06]]),
#      'sample_rate': 44100},
#     149: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\149_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -5.7220e-06, -1.1086e-05,  ...,  8.4639e-06,
#                4.8876e-06,  2.7418e-06]]),
#      'sample_rate': 44100},
#     150: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\150_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.6757e-06, 1.1683e-05,  ..., 1.3590e-05, 8.7023e-06,
#               4.2915e-06]]),
#      'sample_rate': 44100},
#     151: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\151_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.1458e-06,  2.3842e-06,  ..., -2.1458e-06,
#               -9.5367e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     152: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\152_cel.wav',
#      'waveform': tensor([[0.0000e+00, 2.7418e-06, 5.8413e-06,  ..., 7.7486e-06, 5.2452e-06,
#               2.5034e-06]]),
#      'sample_rate': 44100},
#     153: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.5736e-05, 2.8372e-05,  ..., 1.0371e-05, 6.9141e-06,
#               3.4571e-06]]),
#      'sample_rate': 44100}}}},
#  2: {'Marca temporal': '2023/10/11 1:13:47 p.\xa0m. GMT-6',
#   'PHQ-9 Score': 1,
#   'Age': 57,
#   'Gender': 'Female',
#   'Lugar de Residencia': 'Santa Catarina, Nuevo León',
#   'Lugar de Procedencia': nan,
#   'Social Class': 'Working Class',
#   'Institution': 'CAABI',
#   'Medicine': 'Metformina',
#   'Physical Condition': nan,
#   'Mental Health Condition': nan,
#   'Depression Diagnosis (level)': nan,
#   'PHQ-Binary': 0,
#   'audios': {'sm': {'positive': [], 'negative': [], 'neutral': []},
#    'mobile': {1: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_1.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.6226e-06, -5.7220e-06,  ...,  1.0014e-05,
#                6.3181e-06,  3.0994e-06]]),
#      'sample_rate': 44100},
#     10: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_10.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.0994e-06, -5.1260e-06,  ..., -1.4305e-06,
#               -2.2650e-06, -1.5497e-06]]),
#      'sample_rate': 44100},
#     11: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_11.wav',
#      'waveform': tensor([[0.0000e+00, 9.5367e-06, 1.8239e-05,  ..., 3.9339e-06, 2.3842e-06,
#               1.0729e-06]]),
#      'sample_rate': 44100},
#     12: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_12.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.5763e-07,  5.9605e-07,  ..., -7.1526e-07,
#               -8.3447e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     13: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_13.wav',
#      'waveform': tensor([[ 0.0000e+00,  0.0000e+00, -9.5367e-07,  ..., -5.9605e-07,
#               -5.9605e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     14: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_14.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.0994e-06,  7.5102e-06,  ..., -1.2398e-05,
#               -8.5831e-06, -4.4107e-06]]),
#      'sample_rate': 44100},
#     15: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_15.wav',
#      'waveform': tensor([[0.0000e+00, 1.2875e-05, 2.2054e-05,  ..., 1.6689e-06, 1.3113e-06,
#               7.1526e-07]]),
#      'sample_rate': 44100},
#     16: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_16.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.9802e-06, -5.9605e-06,  ..., -6.5565e-06,
#               -5.6028e-06, -3.6955e-06]]),
#      'sample_rate': 44100},
#     17: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_17.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.2902e-05,  6.4611e-05,  ..., -1.0729e-05,
#               -7.2718e-06, -3.4571e-06]]),
#      'sample_rate': 44100},
#     18: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_18.wav',
#      'waveform': tensor([[ 0.0000e+00, -8.4639e-06, -1.8716e-05,  ...,  1.1921e-06,
#                7.1526e-07,  4.7684e-07]]),
#      'sample_rate': 44100},
#     19: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_19.wav',
#      'waveform': tensor([[0.0000e+00, 2.9206e-05, 5.9128e-05,  ..., 3.4571e-06, 1.9073e-06,
#               4.7684e-07]]),
#      'sample_rate': 44100},
#     2: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_2.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.9870e-06, -1.5855e-05,  ..., -1.7881e-06,
#               -1.9073e-06, -1.1921e-06]]),
#      'sample_rate': 44100},
#     20: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_20.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-07,  1.4305e-06,  ..., -3.0994e-06,
#               -1.9073e-06, -1.1921e-06]]),
#      'sample_rate': 44100},
#     21: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_21.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.8678e-06, -1.6928e-05,  ..., -1.2636e-05,
#               -8.2254e-06, -4.0531e-06]]),
#      'sample_rate': 44100},
#     22: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_22.wav',
#      'waveform': tensor([[ 0.0000e+00, -6.4373e-06, -1.1563e-05,  ...,  0.0000e+00,
#               -2.3842e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     23: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_23.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.8147e-06, -7.1526e-06,  ..., -9.5367e-07,
#               -1.0729e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     24: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_24.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.1526e-07, -1.7881e-06,  ..., -1.6689e-05,
#               -1.1206e-05, -5.6028e-06]]),
#      'sample_rate': 44100},
#     25: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_25.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.0490e-05, -2.0981e-05,  ..., -2.6226e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     26: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_26.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.8954e-05,  3.8505e-05,  ..., -1.9670e-05,
#               -1.2875e-05, -6.5565e-06]]),
#      'sample_rate': 44100},
#     3: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_3.wav',
#      'waveform': tensor([[0.0000e+00, 5.6028e-06, 1.1563e-05,  ..., 1.1921e-07, 3.5763e-07,
#               1.1921e-07]]),
#      'sample_rate': 44100},
#     4: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_4.wav',
#      'waveform': tensor([[0.0000e+00, 7.6294e-06, 1.5616e-05,  ..., 1.1921e-06, 4.7684e-07,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     5: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_5.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.4544e-05,  2.9683e-05,  ..., -8.5831e-06,
#               -5.8413e-06, -3.3379e-06]]),
#      'sample_rate': 44100},
#     6: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_6.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.7684e-07, -2.1458e-06,  ...,  4.6492e-06,
#                3.6955e-06,  2.7418e-06]]),
#      'sample_rate': 44100},
#     7: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_7.wav',
#      'waveform': tensor([[0.0000e+00, 2.1458e-06, 5.6028e-06,  ..., 6.0797e-06, 4.1723e-06,
#               2.0266e-06]]),
#      'sample_rate': 44100},
#     8: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_8.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.9870e-06, -1.7047e-05,  ..., -1.7166e-05,
#               -1.3709e-05, -9.4175e-06]]),
#      'sample_rate': 44100},
#     9: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel_9.wav',
#      'waveform': tensor([[ 0.0000e+00,  5.6028e-06,  1.1683e-05,  ..., -8.9407e-06,
#               -6.6757e-06, -3.5763e-06]]),
#      'sample_rate': 44100},
#     100: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\100_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.6226e-06, -5.0068e-06,  ..., -8.3447e-07,
#               -4.7684e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     101: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\101_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.0531e-06, -7.6294e-06,  ...,  1.0729e-06,
#                2.3842e-07,  1.1921e-07]]),
#      'sample_rate': 44100},
#     102: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\102_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.6689e-06, -3.5763e-06,  ..., -1.1921e-06,
#               -9.5367e-07, -5.9605e-07]]),
#      'sample_rate': 44100},
#     103: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\103_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.6492e-06, -1.0371e-05,  ..., -2.3842e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     104: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\104_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.6689e-06, 3.0994e-06,  ..., 5.9605e-07, 2.3842e-07,
#               1.1921e-07]]),
#      'sample_rate': 44100},
#     105: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\105_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-07, -2.3842e-07,  ...,  4.7684e-07,
#                1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     106: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\106_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -5.3644e-06,  ..., -1.1921e-06,
#               -9.5367e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     107: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\107_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.5034e-06,  5.7220e-06,  ..., -1.1921e-07,
#               -2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     108: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\108_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.0994e-06, -6.4373e-06,  ..., -7.5102e-06,
#               -5.4836e-06, -3.4571e-06]]),
#      'sample_rate': 44100},
#     109: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\109_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.1526e-07, -2.5034e-06,  ...,  1.6689e-06,
#                9.5367e-07,  3.5763e-07]]),
#      'sample_rate': 44100},
#     110: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\110_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.4571e-06,  6.6757e-06,  ...,  4.7684e-07,
#                0.0000e+00, -1.1921e-07]]),
#      'sample_rate': 44100},
#     111: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\111_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.5763e-07,  4.7684e-07,  ...,  2.0266e-06,
#                1.3113e-06,  5.9605e-07]]),
#      'sample_rate': 44100},
#     112: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\112_cel.wav',
#      'waveform': tensor([[0.0000e+00, 5.2452e-06, 9.6560e-06,  ..., 6.9141e-06, 4.5300e-06,
#               2.0266e-06]]),
#      'sample_rate': 44100},
#     113: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\113_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  5.7220e-06,  ..., -3.5763e-06,
#               -2.2650e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     114: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\114_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.6689e-06,  2.6226e-06,  ..., -1.3113e-06,
#               -5.9605e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     115: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\115_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  8.3447e-07,  2.0266e-06,  ..., -6.3181e-06,
#               -3.8147e-06, -1.3113e-06]]),
#      'sample_rate': 44100},
#     116: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\116_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-06, -2.3842e-06,  ...,  3.9339e-06,
#                2.8610e-06,  1.4305e-06]]),
#      'sample_rate': 44100},
#     117: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\117_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  3.8147e-06,  ..., -2.1458e-06,
#               -1.3113e-06, -7.1526e-07]]),
#      'sample_rate': 44100},
#     118: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\118_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.4305e-06,  1.1921e-06,  ..., -2.2650e-06,
#               -4.7684e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     119: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\119_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  9.5367e-07,  1.7881e-06,  ..., -7.1526e-07,
#               -5.9605e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     120: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\120_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  4.8876e-06,  1.0371e-05,  ..., -9.5367e-07,
#               -4.7684e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     121: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\121_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  4.4107e-06,  ..., -9.5367e-07,
#               -8.3447e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     122: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\122_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-06,  3.2187e-06,  ..., -4.7684e-07,
#               -3.5763e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     123: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\123_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.4305e-06, -5.1260e-06,  ..., -4.7684e-07,
#               -1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     124: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\124_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -3.3379e-06,  ..., -2.9802e-06,
#               -2.0266e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     125: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\125_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.0729e-06,  2.1458e-06,  ..., -6.9141e-06,
#               -4.8876e-06, -2.5034e-06]]),
#      'sample_rate': 44100},
#     126: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\126_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.9073e-06, 4.0531e-06,  ..., 0.0000e+00, 0.0000e+00,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     127: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\127_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  5.0068e-06,  ...,  8.3447e-07,
#                2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     128: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\128_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  7.2718e-06,  9.6560e-06,  ..., -4.7684e-07,
#                0.0000e+00,  1.1921e-07]]),
#      'sample_rate': 44100},
#     129: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\129_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.9073e-06,  3.8147e-06,  ..., -5.8413e-06,
#               -4.1723e-06, -2.0266e-06]]),
#      'sample_rate': 44100},
#     130: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\130_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  4.7684e-07,  ..., -3.4571e-06,
#               -2.3842e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     131: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\131_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -6.1989e-06, -1.2994e-05,  ...,  4.1723e-06,
#                2.9802e-06,  1.5497e-06]]),
#      'sample_rate': 44100},
#     132: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\132_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  1.1921e-07,  ..., -2.3842e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     133: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\133_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.0133e-05, 2.0146e-05,  ..., 5.7220e-06, 3.6955e-06,
#               1.6689e-06]]),
#      'sample_rate': 44100},
#     134: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\134_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -5.6028e-06, -1.2279e-05,  ..., -1.2994e-05,
#               -9.1791e-06, -5.0068e-06]]),
#      'sample_rate': 44100},
#     135: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\135_cel.wav',
#      'waveform': tensor([[0.0000e+00, 2.0266e-06, 3.2187e-06,  ..., 1.1206e-05, 7.7486e-06,
#               3.8147e-06]]),
#      'sample_rate': 44100},
#     136: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\136_cel.wav',
# ...
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-07, -2.3842e-07,  ...,  4.7684e-07,
#                1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     106: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\106_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -5.3644e-06,  ..., -1.1921e-06,
#               -9.5367e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     107: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\107_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.5034e-06,  5.7220e-06,  ..., -1.1921e-07,
#               -2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     108: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\108_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.0994e-06, -6.4373e-06,  ..., -7.5102e-06,
#               -5.4836e-06, -3.4571e-06]]),
#      'sample_rate': 44100},
#     109: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\109_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -7.1526e-07, -2.5034e-06,  ...,  1.6689e-06,
#                9.5367e-07,  3.5763e-07]]),
#      'sample_rate': 44100},
#     110: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\110_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  3.4571e-06,  6.6757e-06,  ...,  4.7684e-07,
#                0.0000e+00, -1.1921e-07]]),
#      'sample_rate': 44100},
#     111: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\111_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.5763e-07,  4.7684e-07,  ...,  2.0266e-06,
#                1.3113e-06,  5.9605e-07]]),
#      'sample_rate': 44100},
#     112: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\112_cel.wav',
#      'waveform': tensor([[0.0000e+00, 5.2452e-06, 9.6560e-06,  ..., 6.9141e-06, 4.5300e-06,
#               2.0266e-06]]),
#      'sample_rate': 44100},
#     113: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\113_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  5.7220e-06,  ..., -3.5763e-06,
#               -2.2650e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     114: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\114_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.6689e-06,  2.6226e-06,  ..., -1.3113e-06,
#               -5.9605e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     115: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\115_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  8.3447e-07,  2.0266e-06,  ..., -6.3181e-06,
#               -3.8147e-06, -1.3113e-06]]),
#      'sample_rate': 44100},
#     116: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\116_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-06, -2.3842e-06,  ...,  3.9339e-06,
#                2.8610e-06,  1.4305e-06]]),
#      'sample_rate': 44100},
#     117: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\117_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  3.8147e-06,  ..., -2.1458e-06,
#               -1.3113e-06, -7.1526e-07]]),
#      'sample_rate': 44100},
#     118: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\118_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.4305e-06,  1.1921e-06,  ..., -2.2650e-06,
#               -4.7684e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     119: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\119_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  9.5367e-07,  1.7881e-06,  ..., -7.1526e-07,
#               -5.9605e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     120: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\120_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  4.8876e-06,  1.0371e-05,  ..., -9.5367e-07,
#               -4.7684e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     121: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\121_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.3842e-06,  4.4107e-06,  ..., -9.5367e-07,
#               -8.3447e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     122: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\122_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.1921e-06,  3.2187e-06,  ..., -4.7684e-07,
#               -3.5763e-07, -3.5763e-07]]),
#      'sample_rate': 44100},
#     123: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\123_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.4305e-06, -5.1260e-06,  ..., -4.7684e-07,
#               -1.1921e-07,  0.0000e+00]]),
#      'sample_rate': 44100},
#     124: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\124_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.9073e-06, -3.3379e-06,  ..., -2.9802e-06,
#               -2.0266e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     125: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\125_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.0729e-06,  2.1458e-06,  ..., -6.9141e-06,
#               -4.8876e-06, -2.5034e-06]]),
#      'sample_rate': 44100},
#     126: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\126_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.9073e-06, 4.0531e-06,  ..., 0.0000e+00, 0.0000e+00,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     127: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\127_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.2650e-06,  5.0068e-06,  ...,  8.3447e-07,
#                2.3842e-07, -1.1921e-07]]),
#      'sample_rate': 44100},
#     128: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\128_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  7.2718e-06,  9.6560e-06,  ..., -4.7684e-07,
#                0.0000e+00,  1.1921e-07]]),
#      'sample_rate': 44100},
#     129: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\129_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.9073e-06,  3.8147e-06,  ..., -5.8413e-06,
#               -4.1723e-06, -2.0266e-06]]),
#      'sample_rate': 44100},
#     130: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\130_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  4.7684e-07,  ..., -3.4571e-06,
#               -2.3842e-06, -1.0729e-06]]),
#      'sample_rate': 44100},
#     131: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\131_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -6.1989e-06, -1.2994e-05,  ...,  4.1723e-06,
#                2.9802e-06,  1.5497e-06]]),
#      'sample_rate': 44100},
#     132: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\132_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.1921e-07,  1.1921e-07,  ..., -2.3842e-06,
#               -1.7881e-06, -9.5367e-07]]),
#      'sample_rate': 44100},
#     133: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\133_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.0133e-05, 2.0146e-05,  ..., 5.7220e-06, 3.6955e-06,
#               1.6689e-06]]),
#      'sample_rate': 44100},
#     134: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\134_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -5.6028e-06, -1.2279e-05,  ..., -1.2994e-05,
#               -9.1791e-06, -5.0068e-06]]),
#      'sample_rate': 44100},
#     135: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\135_cel.wav',
#      'waveform': tensor([[0.0000e+00, 2.0266e-06, 3.2187e-06,  ..., 1.1206e-05, 7.7486e-06,
#               3.8147e-06]]),
#      'sample_rate': 44100},
#     136: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\136_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.0797e-06, 1.2159e-05,  ..., 2.2650e-06, 2.1458e-06,
#               1.6689e-06]]),
#      'sample_rate': 44100},
#     137: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\137_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -1.0014e-05, -2.0504e-05,  ..., -1.0848e-05,
#               -7.5102e-06, -3.6955e-06]]),
#      'sample_rate': 44100},
#     138: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\138_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.6955e-06, -3.6955e-06,  ..., -2.7418e-06,
#               -1.6689e-06, -7.1526e-07]]),
#      'sample_rate': 44100},
#     139: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\139_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -4.8876e-06, -9.8944e-06,  ...,  3.0994e-06,
#                2.0266e-06,  9.5367e-07]]),
#      'sample_rate': 44100},
#     140: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\140_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.5034e-06, -4.7684e-07,  ...,  1.1921e-07,
#                1.1921e-07,  2.3842e-07]]),
#      'sample_rate': 44100},
#     141: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\141_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -2.1458e-06, -6.5565e-06,  ..., -2.3842e-07,
#               -2.3842e-07, -2.3842e-07]]),
#      'sample_rate': 44100},
#     142: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\142_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.3181e-06, 1.0490e-05,  ..., 2.5034e-06, 1.7881e-06,
#               8.3447e-07]]),
#      'sample_rate': 44100},
#     143: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\143_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  1.7881e-06,  4.1723e-06,  ..., -5.7220e-06,
#               -4.1723e-06, -2.0266e-06]]),
#      'sample_rate': 44100},
#     144: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\144_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.9339e-06, -7.7486e-06,  ...,  5.9605e-07,
#                4.7684e-07,  2.3842e-07]]),
#      'sample_rate': 44100},
#     145: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\145_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.6226e-06,  4.1723e-06,  ..., -4.1723e-06,
#               -2.7418e-06, -1.4305e-06]]),
#      'sample_rate': 44100},
#     146: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\146_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.3113e-06, 2.5034e-06,  ..., 1.1921e-07, 4.7684e-07,
#               3.5763e-07]]),
#      'sample_rate': 44100},
#     147: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\147_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.3113e-06, 2.9802e-06,  ..., 1.0729e-06, 1.1921e-07,
#               0.0000e+00]]),
#      'sample_rate': 44100},
#     148: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\148_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -3.3379e-05, -6.7115e-05,  ..., -1.4663e-05,
#               -9.8944e-06, -4.7684e-06]]),
#      'sample_rate': 44100},
#     149: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\149_cel.wav',
#      'waveform': tensor([[ 0.0000e+00, -5.7220e-06, -1.1086e-05,  ...,  8.4639e-06,
#                4.8876e-06,  2.7418e-06]]),
#      'sample_rate': 44100},
#     150: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\150_cel.wav',
#      'waveform': tensor([[0.0000e+00, 6.6757e-06, 1.1683e-05,  ..., 1.3590e-05, 8.7023e-06,
#               4.2915e-06]]),
#      'sample_rate': 44100},
#     151: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\151_cel.wav',
#      'waveform': tensor([[ 0.0000e+00,  2.1458e-06,  2.3842e-06,  ..., -2.1458e-06,
#               -9.5367e-07, -4.7684e-07]]),
#      'sample_rate': 44100},
#     152: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\152_cel.wav',
#      'waveform': tensor([[0.0000e+00, 2.7418e-06, 5.8413e-06,  ..., 7.7486e-06, 5.2452e-06,
#               2.5034e-06]]),
#      'sample_rate': 44100},
#     153: {'file_path': 'D:/Github/Improving-deep-neural-networks-to-identify-mental-disorders-using-Neural-Architecture-Search/D3T3C/D3TEC Dataset/iPhoneSE2020\\153_cel.wav',
#      'waveform': tensor([[0.0000e+00, 1.5736e-05, 2.8372e-05,  ..., 1.0371e-05, 6.9141e-06,
#               3.4571e-06]]),
#      'sample_rate': 44100}}}}}

# %% [markdown]
# ## SM-27

# %%
df_test = pd.DataFrame(data_dict_updated)

# %%
df_sm =""

# %% [markdown]
# ## iPhone SE 2020

# %%
df_iphone=  ""

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Spectrograms
